# %% [markdown]
# # ETF - Fixed Income

# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
from adjustText import adjust_text
import dataframe_image as dfi

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
excel_etf = 'C:/Users/Bloomberg/Desktop/Gabriel/etf.xlsx'

df_etf = pd.read_excel(excel_etf, "fixedincome", engine = 'openpyxl') 

columnas_etf = ['Unnamed: 21', 'Unnamed: 22']

df_etf.drop(columnas_etf, 1, inplace = True)

df_etf = df_etf.dropna(0, how='all')
df_etf = df_etf.dropna(1, how='all')

df_etf.columns = ['Ticker', 'Name', 'Type', 'Sector', 'Inception Date', 'Curncy', 'Last',
       '30d Avg Vol', 'Avg Bid-Ask Sprd (%)', 'Net. Var', 'Var.% 1D',
       'WTD %', 'Var.% 1M', 'Var.% 3M', 'Var.% 6M', 'YTD %', 'Var.% 1Y',
       'Retrn Dev.Std 3Y', 'Shrp Rat.3Y', 'Exp. Rat.', 'Track Err.']

df_etf["30d Avg Vol"] = df_etf.apply(lambda x: "{:,}".format(x["30d Avg Vol"]), axis=1)

# %%
with pd.option_context('display.precision', 2):
    df_final_etf = df_etf.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#17314c'), 
            ('color', 'white'),
            ('font-family', 'Open Sans'),
            ('font-size', '20px'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'Open Sans'),
          ('font-size', '20px'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', '#DCDCDC')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
]
).hide_index()


dfi.export(df_final_etf,"etf_fi.png")

# %% [markdown]
# # ETF - Equity

# %%
excel_etf_eq = 'C:/Users/Bloomberg/Desktop/Gabriel/etf.xlsx'

df_etf_eq = pd.read_excel(excel_etf, "equity1", engine = 'openpyxl') 

columnas_etf = ['Unnamed: 21', 'Unnamed: 22']

df_etf_eq.drop(columnas_etf, 1, inplace = True)

df_etf_eq = df_etf_eq.dropna(0, how='all')
df_etf_eq = df_etf_eq.dropna(1, how='all')

df_etf_eq.columns = ['Ticker', 'Name', 'Type', 'Sector', 'Inception Date', 'Curncy', 'Last',
       '30d Avg Vol', 'Avg Bid-Ask Sprd (%)', 'Net. Var', 'Var.% 1D',
       'WTD %', 'Var.% 1M', 'Var.% 3M', 'Var.% 6M', 'YTD %', 'Var.% 1Y',
       'Retrn Dev.Std 3Y', 'Shrp Rat.3Y', 'Exp. Rat.', 'Track Err.']

df_etf_eq["30d Avg Vol"] = df_etf_eq.apply(lambda x: "{:,}".format(x["30d Avg Vol"]), axis=1)

# %%
with pd.option_context('display.precision', 2):
    df_final_etf = df_etf.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#17314c'), 
            ('color', 'white'),
            ('font-family', 'Open Sans'),
            ('font-size', '20px'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'Open Sans'),
          ('font-size', '20px'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', '#DCDCDC')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
]
).hide_index()


dfi.export(df_final_etf,"etf_eq.png")

# %% [markdown]
# # ROFEX

# %%
excel_rof = 'G:\Petrini Valores\8. Bloomberg\Informes\Futuros\shofex.xlsx'

df_rof = pd.read_excel(excel_rof, engine = 'openpyxl')

columnas_rof = ['Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16']

df_rof.drop(columnas_rof, 1, inplace = True)

df_rof = df_rof.dropna(0, how='all')
df_rof = df_rof.dropna(1, how='all')

df_rof.columns = ['Especie','Vto.','Último','Var.Neta 1d','Var.% 1d','Días a vto.', 'Volumen','Interés Abierto','Var. Int.Abierto','TNA Impl.%']

df_rof['Días a vto.'] = df_rof['Días a vto.'].astype('Int64')
df_rof['Volumen'] = df_rof['Volumen'].astype('Int64')
df_rof['Interés Abierto'] = df_rof['Interés Abierto'].astype('Int64')
df_rof['Var. Int.Abierto'] = df_rof['Var. Int.Abierto'].astype('Int64')


df_rof["Volumen"] = df_rof.apply(lambda x: "{:,}".format(x["Volumen"]), axis=1)
df_rof['Interés Abierto'] = df_rof.apply(lambda x: "{:,}".format(x['Interés Abierto']), axis=1)
df_rof['Var. Int.Abierto'] = df_rof.apply(lambda x: "{:,}".format(x['Var. Int.Abierto']), axis=1)

df_rof.loc[:,'TNA Impl.%'] *= 100

df_rof['Último'] = df_rof['Último'].round(2)
df_rof['Var.Neta 1d'] = df_rof['Var.Neta 1d'].round(2)
df_rof['Var.% 1d'] = df_rof['Var.% 1d'].round(2)
df_rof['TNA Impl.%'] = df_rof['TNA Impl.%'].round(2)

df_rof.replace(0," ", inplace=True)
df_rof.replace("0"," ", inplace=True)

# %%
with pd.option_context('display.precision', 2):
    df_final_rof = df_rof.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#17314c'), 
            ('color', 'white'),
            ('font-family', 'Open Sans'),
            ('font-size', '14px'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'Open Sans'),
          ('font-size', '12px'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', '#DCDCDC')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
]
).hide_index()

dfi.export(df_final_rof,"Rofex.png",)

# %% [markdown]
# # ROFEX - TNA implícita curva

# %%
df_rof = df_rof.drop(axis = 0, index = 7)

# %%
from datetime import datetime
datem = datetime.today().strftime("%m-%Y")
datem = datetime.strptime(datem, "%m-%Y")

meses = pd.date_range(datem, periods = 7, freq = 'MS')

w = [1,2,3,4,5,6,7]
tna = df_rof['TNA Impl.%'].astype('float')
meses = meses.strftime('%m-%Y')

# %%
poly_degree_rof = 2
curva_rof = np.polyfit(w, tna, poly_degree_rof)

start_rof = 0
stop_rof = 7
num_points_rof = 10000
arbitrary_times_rof = np.linspace(start_rof, stop_rof, num_points_rof)

poly_rof = np.polyval(curva_rof, arbitrary_times_rof)

# %%
main_font = "Open Sans"
plot_color = "grey"

plot_color_pr = "navy"
#plot_color_ny = "grey"

font_dict1 = {'fontfamily':'Open Sans','color':'black','size':6}
font_dict2 = {'fontfamily':'Open Sans','color':'grey','size':6}
    

fuente = "FUENTE: Petrini Valores en base a datos de Bloomberg"    


from datetime import date
today = date.today()
t1 = today.strftime("%d/%m/%Y")

def plot_mtcars(adjust=True, *args, **kwargs):
    fig, ax = plt.subplots(figsize=(6, 3))
    fig.set_facecolor("white")
    plt.rcParams["figure.figsize"] = (10,7)
    ax.plot(arbitrary_times_rof, poly_rof,c = plot_color_pr, zorder = 1)
    ax.scatter(meses, tna, s = 5, c = plot_color_pr, zorder = 0) 
    texts = []
    for x, y, s in zip(meses, tna, df_rof['TNA Impl.%']):
        texts.append(plt.text(x, y, s, size=6))
    plt.xlabel('Vencimiento', fontsize=8)
    plt.ylabel('TNA Implícita %', fontsize=8)
    #fig.text(0.15,1,"BONOS PROVINCIALES EN USD", fontsize=9, fontweight="bold", font = main_font)        
    #fig.text(0.15,0.95, t1 ,fontweight="regular", fontsize=6)
    fig.text(0.15,0,fuente, fontdict = font_dict2, fontstyle = "italic")

    ax.grid(False)

    ax.set_xlim(-1,7)
    ax.set_ylim(10,50)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_color(plot_color)
    ax.spines['left'].set_color(plot_color)

    ax.tick_params(axis="x",color = "black", labelcolor = "black" ,labelsize = 7)
    ax.tick_params(axis="y",color = "black", labelcolor = "black" ,labelsize = 7)
    

    ax.set_position([0.1,0.1,0.5,0.5])

    plt.style.use('default')
    plt.rcParams['font.family'] = main_font
    if adjust:
        plt.title('%s iterations' % adjust_text(texts, arrowprops=dict(arrowstyle="-", color='k', lw=0.5), **kwargs), c = "white")
    else:
        plt.title('Original')

plot_mtcars()   

path_png = r'C:/Users/Bloomberg/Desktop/Gabriel/rofex_curva.png'
    
plt.tight_layout()
plt.savefig(path_png, dpi = 300)
# Out:
# findfont: Font family ['Open Sans'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # FCI - Money Market

# %%
excel_fci = r"G:\Petrini Valores\8. Bloomberg\Informes\FCI\fci.xlsx"

df_fci = pd.read_excel(excel_fci, "moneymkt", engine = 'openpyxl') 

columnas_fci = ['Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47',
                'Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                '2','7','28','90','77','FSTPESB AR Equity']

df_fci.drop('Cod', 1, inplace = True)

df_fci = df_fci.dropna(0, how='all')
df_fci = df_fci.dropna(1, how='all')

df_fci.columns = ['Jerarquia', 'Ticker', 'Fondo', 'Sociedad Gerente', 'Último', 'Moneda',
                  'Tot. Assets (Mill.)', '%2D', '%5D', '%1M', '%3M', '%YTD', 'Dt Last Updt',
                  'TNA %2D', 'TNA %5D', 'TNA %1M', 'TNA %3M', 'TNA %YTD', 'Rnkg 2d', 'Rnkg 5d', 'Rnkg 1m', 'Rnkg 3m',
                  'Rnkg ytd']

df_fci = df_fci[['Fondo', 'Sociedad Gerente', 'Último', 'Moneda',
                 'Tot. Assets (Mill.)','TNA %2D', 'TNA %5D', 'TNA %1M', 'TNA %3M', 'TNA %YTD',
                 'Rnkg 2d', 'Rnkg 5d', 'Rnkg 1m', 'Rnkg 3m','Rnkg ytd']]

df_fci['Último'] = df_fci['Último'].astype('float64')
df_fci['Tot. Assets (Mill.)'] = df_fci['Tot. Assets (Mill.)'].astype('float64')
df_fci['TNA %2D'] = df_fci['TNA %2D'].astype('float64')
df_fci['TNA %5D'] = df_fci['TNA %5D'].astype('float64')
df_fci['TNA %1M'] = df_fci['TNA %1M'].astype('float64')
df_fci['TNA %3M'] = df_fci['TNA %3M'].astype('float64')
df_fci['TNA %YTD'] = df_fci['TNA %YTD'].astype('float64')


df_fci['Último'] = df_fci['Último'].round(2)
df_fci['Tot. Assets (Mill.)'] = df_fci['Tot. Assets (Mill.)'].round(2)
df_fci['TNA %2D'] = df_fci['TNA %2D'].round(2)
df_fci['TNA %5D'] = df_fci['TNA %5D'].round(2)
df_fci['TNA %1M'] = df_fci['TNA %1M'].round(2)
df_fci['TNA %3M'] = df_fci['TNA %3M'].round(2)
df_fci['TNA %YTD'] = df_fci['TNA %YTD'].round(2)

df_fci["Último"] = df_fci.apply(lambda x: "{:,}".format(x["Último"]), axis=1)
df_fci["Tot. Assets (Mill.)"] = df_fci.apply(lambda x: "{:,}".format(x["Tot. Assets (Mill.)"]), axis=1)

df_fci.replace(0," ", inplace=True)
df_fci.replace("0"," ", inplace=True)

# %%
with pd.option_context('display.precision', 2):
    df_final_fci = df_fci.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#17314c'), 
            ('color', 'white'),
            ('font-family', 'Open Sans'),
            ('font-size', '20px'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'Open Sans'),
          ('font-size', '20px'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', '#DCDCDC')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
]
).hide_index()


dfi.export(df_final_fci,"fci_mm.png")

# %% [markdown]
# # FCI - Dolar Linked

# %%
excel_fcidl = r"G:\Petrini Valores\8. Bloomberg\Informes\FCI\fci.xlsx"

df_fcidl = pd.read_excel(excel_fcidl, "dolar", engine = 'openpyxl') 

df_fcidl.columns = ['Jerarquía', 'Ticker', 'Cod', 'Fondo', 'Sociedad Gerente', 'Último', 'Moneda',
       'Tot. Assets (Mill.)', '%2D', '%5D', '%1M', '%3M', '%YTD', 'Dt Last Updt', 'Rnkg 2d', 'Rnkg 5d', 'Rnkg 1m', 'Rnkg 3m',
       'Rnkg ytd']

df_fcidl = df_fcidl[['Fondo', 'Sociedad Gerente', 'Último', 'Moneda',
       'Tot. Assets (Mill.)', '%2D', '%5D', '%1M', '%3M', '%YTD', 'Rnkg 2d', 'Rnkg 5d', 'Rnkg 1m', 'Rnkg 3m',
       'Rnkg ytd']]

df_fcidl['Último'] = df_fcidl['Último'].astype('float64')
df_fcidl['Tot. Assets (Mill.)'] = df_fcidl['Tot. Assets (Mill.)'].astype('float64')
df_fcidl['%2D'] = df_fcidl['%2D'].astype('float64')
df_fcidl['%5D'] = df_fcidl['%5D'].astype('float64')
df_fcidl['%1M'] = df_fcidl['%1M'].astype('float64')
df_fcidl['%3M'] = df_fcidl['%3M'].astype('float64')
df_fcidl['%YTD'] = df_fcidl['%YTD'].astype('float64')


df_fcidl['Último'] = df_fcidl['Último'].round(2)
df_fcidl['Tot. Assets (Mill.)'] = df_fcidl['Tot. Assets (Mill.)'].round(2)
df_fcidl['%2D'] = df_fcidl['%2D'].round(3)
df_fcidl['%5D'] = df_fcidl['%5D'].round(3)
df_fcidl['%1M'] = df_fcidl['%1M'].round(3)
df_fcidl['%3M'] = df_fcidl['%3M'].round(3)
df_fcidl['%YTD'] = df_fcidl['%YTD'].round(3)

df_fcidl["Último"] = df_fcidl.apply(lambda x: "{:,}".format(x["Último"]), axis=1)
df_fcidl["Tot. Assets (Mill.)"] = df_fcidl.apply(lambda x: "{:,}".format(x["Tot. Assets (Mill.)"]), axis=1)

df_fcidl.replace(0," ", inplace=True)
df_fcidl.replace("0"," ", inplace=True)

# %%
with pd.option_context('display.precision', 2):
    df_final_fcidl = df_fcidl.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#17314c'), 
            ('color', 'white'),
            ('font-family', 'Open Sans'),
            ('font-size', '20px'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'Open Sans'),
          ('font-size', '20px'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', '#DCDCDC')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
]
).hide_index()


dfi.export(df_final_fcidl,"fci_dl.png")

# %% [markdown]
# # FCI - T+1

# %%
excel_fcit = r"G:\Petrini Valores\8. Bloomberg\Informes\FCI\fci.xlsx"

df_fcit = pd.read_excel(excel_fcit, "t+1", engine = 'openpyxl') 

df_fcit.columns = ['Jerarquía', 'Ticker', 'Cod', 'Fondo', 'Sociedad Gerente', 'Último', 'Moneda',
       'Tot. Assets (Mill.)', '%2D', '%5D', '%1M', '%3M', '%YTD', 'Dt Last Updt', 'Rnkg 2d', 'Rnkg 5d', 'Rnkg 1m', 'Rnkg 3m',
       'Rnkg ytd']

df_fcit = df_fcit[['Fondo', 'Sociedad Gerente', 'Último', 'Moneda',
       'Tot. Assets (Mill.)', '%2D', '%5D', '%1M', '%3M', '%YTD', 'Rnkg 2d', 'Rnkg 5d', 'Rnkg 1m', 'Rnkg 3m',
       'Rnkg ytd']]

df_fcit['Último'] = df_fcit['Último'].astype('float64')
df_fcit['Tot. Assets (Mill.)'] = df_fcit['Tot. Assets (Mill.)'].astype('float64')
df_fcit['%2D'] = df_fcit['%2D'].astype('float64')
df_fcit['%5D'] = df_fcit['%5D'].astype('float64')
df_fcit['%1M'] = df_fcit['%1M'].astype('float64')
df_fcit['%3M'] = df_fcit['%3M'].astype('float64')
df_fcit['%YTD'] = df_fcit['%YTD'].astype('float64')


df_fcit['Último'] = df_fcit['Último'].round(2)
df_fcit['Tot. Assets (Mill.)'] = df_fcit['Tot. Assets (Mill.)'].round(2)
df_fcit['%2D'] = df_fcit['%2D'].round(3)
df_fcit['%5D'] = df_fcit['%5D'].round(3)
df_fcit['%1M'] = df_fcit['%1M'].round(3)
df_fcit['%3M'] = df_fcit['%3M'].round(3)
df_fcit['%YTD'] = df_fcit['%YTD'].round(3)

df_fcit["Último"] = df_fcit.apply(lambda x: "{:,}".format(x["Último"]), axis=1)
df_fcit["Tot. Assets (Mill.)"] = df_fcit.apply(lambda x: "{:,}".format(x["Tot. Assets (Mill.)"]), axis=1)

df_fcit.replace(0," ", inplace=True)
df_fcit.replace("0"," ", inplace=True)

df_fcit = df_fcit.dropna(0)

# %%
with pd.option_context('display.precision', 2):
    df_final_fcit = df_fcit.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#17314c'), 
            ('color', 'white'),
            ('font-family', 'Open Sans'),
            ('font-size', '20px'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'Open Sans'),
          ('font-size', '20px'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', '#DCDCDC')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
]
).hide_index()


dfi.export(df_final_fcit,"fci_t+1.png")
df_final_fcit
# Out:
# <style  type="text/css" >
#     #T_7d54a930_8bf3_11eb_96a9_00155d1b3225 th {
#           background: #17314c;
#           color: white;
#           font-family: Open Sans;
#           font-size: 20px;
#           text-align: center;
#     }    #T_7d54a930_8bf3_11eb_96a9_00155d1b3225 td {
#           font-family: Open Sans;
#           font-size: 20px;
#           text-align: center;
#     }    #T_7d54a930_8bf3_11eb_96a9_00155d1b3225 tr:nth-of-type(odd) {
#           background: #DCDCDC;
#     }    #T_7d54a930_8bf3_11eb_96a9_00155d1b3225 tr:nth-of-type(even) {
#           background: white;
# ...

# %% [markdown]
# # FCI - CER

# %%
excel_fcicer = r"G:\Petrini Valores\8. Bloomberg\Informes\FCI\fci.xlsx"

df_fcicer = pd.read_excel(excel_fcicer, "cer", engine = 'openpyxl') 

df_fcicer.columns = ['Jerarquía', 'Ticker', 'Cod', 'Fondo', 'Sociedad Gerente', 'Último', 'Moneda',
       'Tot. Assets (Mill.)', '%2D', '%5D', '%1M', '%3M', '%YTD', 'Dt Last Updt', 'Rnkg 2d', 'Rnkg 5d', 'Rnkg 1m', 'Rnkg 3m',
       'Rnkg ytd']

df_fcicer = df_fcicer[['Fondo', 'Sociedad Gerente', 'Último', 'Moneda',
       'Tot. Assets (Mill.)', '%2D', '%5D', '%1M', '%3M', '%YTD', 'Rnkg 2d', 'Rnkg 5d', 'Rnkg 1m', 'Rnkg 3m',
       'Rnkg ytd']]

df_fcicer['Último'] = df_fcicer['Último'].astype('float64')
df_fcicer['Tot. Assets (Mill.)'] = df_fcicer['Tot. Assets (Mill.)'].astype('float64')
df_fcicer['%2D'] = df_fcicer['%2D'].astype('float64')
df_fcicer['%5D'] = df_fcicer['%5D'].astype('float64')
df_fcicer['%1M'] = df_fcicer['%1M'].astype('float64')
df_fcicer['%3M'] = df_fcicer['%3M'].astype('float64')
df_fcicer['%YTD'] = df_fcicer['%YTD'].astype('float64')


df_fcicer['Último'] = df_fcicer['Último'].round(2)
df_fcicer['Tot. Assets (Mill.)'] = df_fcicer['Tot. Assets (Mill.)'].round(2)
df_fcicer['%2D'] = df_fcicer['%2D'].round(3)
df_fcicer['%5D'] = df_fcicer['%5D'].round(3)
df_fcicer['%1M'] = df_fcicer['%1M'].round(3)
df_fcicer['%3M'] = df_fcicer['%3M'].round(3)
df_fcicer['%YTD'] = df_fcicer['%YTD'].round(3)

df_fcicer["Último"] = df_fcicer.apply(lambda x: "{:,}".format(x["Último"]), axis=1)
df_fcicer["Tot. Assets (Mill.)"] = df_fcicer.apply(lambda x: "{:,}".format(x["Tot. Assets (Mill.)"]), axis=1)

df_fcicer.replace(0," ", inplace=True)
df_fcicer.replace("0"," ", inplace=True)

# %%
with pd.option_context('display.precision', 2):
    df_final_fcicer = df_fcicer.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#17314c'), 
            ('color', 'white'),
            ('font-family', 'Open Sans'),
            ('font-size', '20px'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'Open Sans'),
          ('font-size', '20px'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', '#DCDCDC')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
]
).hide_index()


dfi.export(df_final_fcicer,"fci_cer.png")

# %% [markdown]
# # FCI - PYME

# %%
excel_fcipy = r"G:\Petrini Valores\8. Bloomberg\Informes\FCI\fci.xlsx"

df_fcipy = pd.read_excel(excel_fcipy, "pyme", engine = 'openpyxl') 

df_fcipy.columns = ['Jerarquía', 'Ticker', 'Cod', 'Fondo', 'Sociedad Gerente', 'Último', 'Moneda',
       'Tot. Assets (Mill.)', '%2D', '%5D', '%1M', '%3M', '%YTD', 'Dt Last Updt', 'Rnkg 2d', 'Rnkg 5d', 'Rnkg 1m', 'Rnkg 3m',
       'Rnkg ytd']

df_fcipy = df_fcipy[['Fondo', 'Sociedad Gerente', 'Último', 'Moneda',
       'Tot. Assets (Mill.)', '%2D', '%5D', '%1M', '%3M', '%YTD', 'Rnkg 2d', 'Rnkg 5d', 'Rnkg 1m', 'Rnkg 3m',
       'Rnkg ytd']]

df_fcipy['Último'] = df_fcipy['Último'].astype('float64')
df_fcipy['Tot. Assets (Mill.)'] = df_fcipy['Tot. Assets (Mill.)'].astype('float64')
df_fcipy['%2D'] = df_fcipy['%2D'].astype('float64')
df_fcipy['%5D'] = df_fcipy['%5D'].astype('float64')
df_fcipy['%1M'] = df_fcipy['%1M'].astype('float64')
df_fcipy['%3M'] = df_fcipy['%3M'].astype('float64')
df_fcipy['%YTD'] = df_fcipy['%YTD'].astype('float64')


df_fcipy['Último'] = df_fcipy['Último'].round(2)
df_fcipy['Tot. Assets (Mill.)'] = df_fcipy['Tot. Assets (Mill.)'].round(2)
df_fcipy['%2D'] = df_fcipy['%2D'].round(3)
df_fcipy['%5D'] = df_fcipy['%5D'].round(3)
df_fcipy['%1M'] = df_fcipy['%1M'].round(3)
df_fcipy['%3M'] = df_fcipy['%3M'].round(3)
df_fcipy['%YTD'] = df_fcipy['%YTD'].round(3)

df_fcipy["Último"] = df_fcipy.apply(lambda x: "{:,}".format(x["Último"]), axis=1)
df_fcipy["Tot. Assets (Mill.)"] = df_fcipy.apply(lambda x: "{:,}".format(x["Tot. Assets (Mill.)"]), axis=1)

df_fcipy.replace(0," ", inplace=True)
df_fcipy.replace("0"," ", inplace=True)

# %%
with pd.option_context('display.precision', 2):
    df_final_fcipy = df_fcipy.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#17314c'), 
            ('color', 'white'),
            ('font-family', 'Open Sans'),
            ('font-size', '20px'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'Open Sans'),
          ('font-size', '20px'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', '#DCDCDC')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
]
).hide_index()


dfi.export(df_final_fcicer,"fci_py.png")
