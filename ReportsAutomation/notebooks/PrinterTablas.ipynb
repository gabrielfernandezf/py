# %% [markdown]
# # BONOS SOBERANOS

# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
from adjustText import adjust_text
import dataframe_image as dfi

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
excel = 'C:/Users/Bloomberg/Desktop/Gabriel/soberanos.xlsx'

df = pd.read_excel(excel, engine = 'openpyxl') 

df = df.dropna(0, how='all')
df = df.dropna(1, how='all')

df.columns = ['Bono','Código Local','Último','Var % 1d','WTD %', 'YTM %','DM','Cupón','Vencimiento', 'Próx. Vto.', 'Int. Dev.', 'Z-Spread', 'Monto Emisión','Den. Mín.','ISIN','Ley', 'cod_bbg']
#df.set_index("Bono", inplace = True)

redondeo = df.round(2)#,'Var % 1d','WTD %', 'YTM %','DM','Interés Devegando', 'Z-Spread', 'Monto Emisión','Denominación Mínima'].round(2)
df.drop('cod_bbg', axis=1, inplace=True)

df['Monto Emisión'] = df['Monto Emisión'].astype('int64')
df['Z-Spread'] = df['Z-Spread'].astype('int64')

df['Monto Emisión'] = df.apply(lambda x: "{:,}".format(x['Monto Emisión']), axis=1)
df['Z-Spread'] = df.apply(lambda x: "{:,}".format(x['Z-Spread']), axis=1)

# %%
df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Bono</th>\n      <th>Código Local</th>\n      <th>Último</th>\n      <th>Var % 1d</th>\n      <th>WTD %</th>\n      <th>YTM %</th>\n      <th>DM</th>\n      <th>Cupón</th>\n      <th>Vencimiento</th>\n      <th>Próx. Vto.</th>\n      <th>Int. Dev.</th>\n      <th>Z-Spread</th>\n      <th>Monto Emisión</th>\n      <th>Den. Mín.</th>\n      <th>ISIN</th>\n      <th>Ley</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>ARGBON 1 07/09/29</td>\n      <td>AL29</td>\n      <td>36.50</td>\n      <td>-0.02</td>\n      <td>-2.49</td>\n      <td>19.18</td>\n      <td>4.99</td>\n      <td>1.00</td>\n      <td>2029-07-09</td>\n      <td>2021-07-09</td>\n      <td>0.47</td>\n      <td>2,080</td>\n      <td>2,188,820,823</td>\n      <td>1.0</td>\n      <td>ARARGE3209Y4</td>\n      <td>AR</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>ARGBON 0 1/8 07/0
# ...

# %%
with pd.option_context('display.precision', 2):
    df_final = df.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#17314c'), 
            ('color', 'white'),
            ('font-family', 'Open Sans'),
            ('font-size', '14px'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'Open Sans'),
          ('font-size', '12px'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', '#DCDCDC')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
]
).hide_index()

    
#dfi.export(df_final,"SoberanosUSD.png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-049002ae40bc> in <module>
#      23
#      24
# ---> 25 df = pd.read_table(df_final)
#      26 #dfi.export(df_final,"SoberanosUSD.png")
#
# ...

# %% [markdown]
# # BONOS PROVINCIALES

# %%
excel_prov = 'C:/Users/Bloomberg/Desktop/Gabriel/provinciales.xlsx'

df_pr = pd.read_excel(excel_prov, engine = 'openpyxl') 

df_pr = df_pr.dropna(0, how='all')
df_pr = df_pr.dropna(1, how='all')

df_pr.columns = ['Bono','Código Local','Último','Var % 1d','WTD %', 'YTM %','DM','Cupón','Vencimiento', 'Próx. Vto.', 'Int. Dev.', 'Z-Spread', 'Monto Emisión','Den. Mín.','ISIN']
#df.set_index("Bono", inplace = True)

redondeo = df_pr.round(2)

df_pr['Monto Emisión'] = df_pr['Monto Emisión'].astype('int64')
df_pr['Z-Spread'] = df_pr['Z-Spread'].astype('int64')

df_pr['Monto Emisión'] = df_pr.apply(lambda x: "{:,}".format(x['Monto Emisión']), axis=1)
df_pr['Z-Spread'] = df_pr.apply(lambda x: "{:,}".format(x['Z-Spread']), axis=1)

# %%
with pd.option_context('display.precision', 2):
    df_final_pr = df_pr.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#17314c'), 
            ('color', 'white'),
            ('font-family', 'Open Sans'),
            ('font-size', '14px'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'Open Sans'),
          ('font-size', '12px'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', '#DCDCDC')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
]
).hide_index()

dfi.export(df_final_pr,"ProvincialesUSD.png")

# %% [markdown]
# # BONOS CORPORATIVOS

# %%
excel_corp = 'C:/Users/Bloomberg/Desktop/Gabriel/corporativos.xlsx'

df_cr = pd.read_excel(excel_corp, engine = 'openpyxl') 

df_cr = df_cr.dropna(0, how='all')
df_cr = df_cr.dropna(1, how='all')

df_cr.drop('cod_bbg', axis=1, inplace=True)

df_cr.columns = ['Bono','Código Local','Último','Var % 1d','WTD %', 'YTM %','DM','Cupón','Vencimiento', 'Próx. Vto.', 'Int. Dev.', 'Z-Spread', 'Monto Emisión', 'Callable','Den. Mín.','ISIN', 'Sector']

#df.set_index("Bono", inplace = True)

redondeo = df_pr.round(2)

df_cr['Monto Emisión'] = df_cr['Monto Emisión'].astype('int64')
df_cr['Z-Spread'] = df_cr['Z-Spread'].astype('int64')

df_cr['Monto Emisión'] = df_cr.apply(lambda x: "{:,}".format(x['Monto Emisión']), axis=1)
df_cr['Z-Spread'] = df_cr.apply(lambda x: "{:,}".format(x['Z-Spread']), axis=1)

# %%
with pd.option_context('display.precision', 2):
    df_final_cr = df_cr.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#17314c'), 
            ('color', 'white'),
            ('font-family', 'Open Sans'),
            ('font-size', '14px'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'Open Sans'),
          ('font-size', '12px'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', '#DCDCDC')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
]
).hide_index()

dfi.export(df_final_cr,"CorporativosUSD.png",)

# %% [markdown]
# # LETRAS EN PESOS

# %%
excel_pub = 'G:\Petrini Valores\8. Bloomberg\Informes\Renta Fija\Informe Publicos Pesos.xlsx'

df_pub = pd.read_excel(excel_pub,"pesosmm", engine = 'openpyxl') 


redondeo = df_pub.round(2)

columnas_nat = ['Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51']

df_pub.drop(columnas_nat, 1, inplace = True)

df_pub = df_pub.dropna(0, how='all')
df_pub = df_pub.dropna(1, how='all')

df_pub.columns = ['Especie','Código','Cupón','Precio AR$','TNA (%)','YTM (%)','DM','Volumen','VR', 'VT', 'Paridad', 'Fecha emisión', 'Maturity', 'Monto Emisión','ISIN']

df_pub["Volumen"] = df_pub["Volumen"].astype('int64')
df_pub['Monto Emisión'] = df_pub['Monto Emisión'].astype('int64')

df_pub["Volumen"] = df_pub.apply(lambda x: "{:,}".format(x["Volumen"]), axis=1)
df_pub['Monto Emisión'] = df_pub.apply(lambda x: "{:,}".format(x['Monto Emisión']), axis=1)

df_pub['Fecha emisión'] = df_pub['Fecha emisión'].dt.strftime('%d/%m/%Y')
df_pub['Maturity'] = df_pub['Maturity'].dt.strftime('%d/%m/%Y')

df_pub.loc[:,'Precio AR$'] *= 100
df_pub.loc[:,'TNA (%)'] *= 100
df_pub.loc[:,'YTM (%)'] *= 100
df_pub.loc[:,'VR'] *= 100
df_pub.loc[:,'VT'] *= 100

k = []
for i in df_pub['Cupón']:
    if i == 0: 
        k.append(str(i)+"%")
    else:
        k.append(i)


df_pub['Cupón'] = k

# %%
with pd.option_context('display.precision', 2):
    df_final_pub = df_pub.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#17314c'), 
            ('color', 'white'),
            ('font-family', 'Open Sans'),
            ('font-size', '14px'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'Open Sans'),
          ('font-size', '12px'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', '#DCDCDC')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
]
).hide_index()

dfi.export(df_final_pub,"LetrasARS.png",)

# %% [markdown]
# # BONOS SOBERANOS EN PESOS

# %%
excel_pes = 'G:\Petrini Valores\8. Bloomberg\Informes\Renta Fija\Informe Publicos Pesos.xlsx'

df_pes = pd.read_excel(excel_pes,"pesosbonos", engine = 'openpyxl')

columnas_na = ['Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51']

df_pes.drop(columnas_na, 1, inplace = True)

df_pes = df_pes.dropna(0, how='all')
df_pes = df_pes.dropna(1, how='all')

df_pes.columns = ['Especie','Código','Cupón','Precio AR$','TNA (%)','YTM (%)','DM','Volumen','VR', 'VT', 'Paridad', 'Fecha emisión', 'Maturity', 'Monto Emisión','ISIN','Tipo']

df_pes["Volumen"] = df_pes["Volumen"].astype('int64')
df_pes['Monto Emisión'] = df_pes['Monto Emisión'].astype('int64')

df_pes["Volumen"] = df_pes.apply(lambda x: "{:,}".format(x["Volumen"]), axis=1)
df_pes['Monto Emisión'] = df_pes.apply(lambda x: "{:,}".format(x['Monto Emisión']), axis=1)

df_pes['Fecha emisión'] = df_pes['Fecha emisión'].dt.strftime('%d/%m/%Y')
df_pes['Maturity'] = df_pes['Maturity'].dt.strftime('%d/%m/%Y')

df_pes.loc[:,'Precio AR$'] *= 100
df_pes.loc[:,'TNA (%)'] *= 100
df_pes.loc[:,'YTM (%)'] *= 100
df_pes.loc[:,'VR'] *= 100
df_pes.loc[:,'VT'] *= 100

#df_pes['TNA (%)'] = df_pes['TNA (%)'][4:18].astype('str')
df_pes.loc[np.isnan(df_pes.iloc[:,4]),'TNA (%)'] = 0
df_pes['TNA (%)'] = df_pes['TNA (%)'].round(2)

# %%
h = []
for i in df_pes['TNA (%)']:
    if i == 0:
        h.append("-")
    else:
        h.append(i)
        
        
df_pes['TNA (%)'] = h


g = []
for i in df_pes['ISIN']:
    if i == 'NaN':
        g.append("-")
    else:
        g.append(i)
        
df_pes['ISIN'] = g

df_pes
# Out:
#              Especie Código        Cupón   Precio AR$ TNA (%)    YTM (%)  \
# 0               TB21  TB21P       B + 1%   103.101013    3.48  43.199092
# 1         Bocon 2022   PR15       B + 0%   100.101623    4.56  44.618105
# 2         Bonar 2022  AA22P       B + 2%   105.496590    4.12  44.038723
# 3        Bono Badlar  TB23P       B + 1%   102.386722    2.17  41.491927
# 4          Boncer 21  T2X1P   CER + 1,1%   136.600156       -  -8.070256
# 5          Boncer 21  TC21P   CER + 2,5%   458.595645       -  -2.721231
# 6          Boncer 22  TX22P   CER + 1,2%   139.494996       -  -0.219879
# 7         Bocon 2024   PR13     CER + 2%   735.026592       -  -1.479867
# 8          Boncer 22   T2X2   CER + 1,3%   133.247564       -   0.420441
# 9          Boncer 23  TC23P     CER + 4%   329.983025       -   1.808100
# 10         Boncer 23  TX23P   CER + 1,4%   135.902540       -   2.161557
# 11         Boncer 23   T2X3  CER + 1,45%   119.695722       -   3.144336
# ...

# %%
with pd.option_context('display.precision', 2):
    df_final_pes = df_pes.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#17314c'), 
            ('color', 'white'),
            ('font-family', 'Open Sans'),
            ('font-size', '14px'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'Open Sans'),
          ('font-size', '12px'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', '#DCDCDC')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
]
).hide_index()

dfi.export(df_final_pes,"SoberanosARS.png",) 

df_final_pes
# Out:
# <style  type="text/css" >
#     #T_905750f4_8736_11eb_856b_00155d1b3225 th {
#           background: #17314c;
#           color: white;
#           font-family: Open Sans;
#           font-size: 14px;
#           text-align: center;
#     }    #T_905750f4_8736_11eb_856b_00155d1b3225 td {
#           font-family: Open Sans;
#           font-size: 12px;
#           text-align: center;
#     }    #T_905750f4_8736_11eb_856b_00155d1b3225 tr:nth-of-type(odd) {
#           background: #DCDCDC;
#     }    #T_905750f4_8736_11eb_856b_00155d1b3225 tr:nth-of-type(even) {
#           background: white;
# ...
