# %% [markdown]
# #***ADECUACIÓN DE BASE DE DATOS***
#
# ---
#
#
#
# ---

# %%
# !pip install chart_studio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: chart_studio in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from chart_studio) (2.23.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from chart_studio) (1.3.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from chart_studio) (5.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from chart_studio) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly->chart_studio) (8.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (2022.6.15)

# %%
import numpy as np
import pandas as pd 

from sklearn import preprocessing # Data Scaling
from sklearn import decomposition #PCA
from sklearn.cluster import KMeans

import chart_studio
from chart_studio import plotly as py
import plotly.graph_objs as go
import chart_studio.tools as tls
import plotly.express as px

# %%
#Login Chart-Studio Plotly
username = 'gabriel.fernandez'
api_key = 'GuaZQhD2Q8wKlLhiomcn'

chart_studio.tools.set_credentials_file(username=username, api_key=api_key)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import glob
df = pd.concat(map(pd.read_csv, glob.glob('/content/drive/My Drive/Agencia/molineria/*.csv')))

# %%
df1 = df[['year', 'reporter_code','reporter', 'reporter_iso', 'partner_code', 'partner',
       'partner_iso', 'commodity_code','commodity', 'trade_value_usd']]
df1.head()

# %%
df1['commodity_code'].astype('int', errors='ignore')
df1.head()

# %%
ncm = [71320.0] 
    
# selecting rows based on condition 
df1.loc[df1['commodity_code'].isin(ncm)]
# Out:
#          year  reporter_code reporter reporter_iso  partner_code  \
# 0      2017.0            8.0  Albania          ALB           0.0
# 1      2017.0            8.0  Albania          ALB         381.0
# 2      2017.0           12.0  Algeria          DZA           0.0
# 3      2017.0           12.0  Algeria          DZA          32.0
# 4      2017.0           12.0  Algeria          DZA          50.0
# ...       ...            ...      ...          ...           ...
# 76706  2018.0          434.0    Libya          LBY         784.0
# 76707  2018.0          434.0    Libya          LBY         788.0
# 76708  2018.0          434.0    Libya          LBY         792.0
# 76709  2018.0          434.0    Libya          LBY         804.0
# 76710  2018.0          434.0    Libya          LBY         818.0
#
#                     partner partner_iso  commodity_code  \
# 0                     World         WLD         71320.0
# 1                     Italy         ITA         71320.0
# 2                     World         WLD         71320.0
# 3                 Argentina         ARG         71320.0
# 4                Bangladesh         BGD         71320.0
# ...                     ...         ...             ...
# 76706  United Arab Emirates         ARE         71320.0
# 76707               Tunisia         TUN         71320.0
# 76708                Turkey         TUR         71320.0
# 76709               Ukraine         UKR         71320.0
# 76710                 Egypt         EGY         71320.0
#
#                                                commodity  trade_value_usd
# 0      Vegetables, leguminous; chickpeas (garbanzos),...            208.0
# 1      Vegetables, leguminous; chickpeas (garbanzos),...            208.0
# 2      Vegetables, leguminous; chickpeas (garbanzos),...      139911999.0
# 3      Vegetables, leguminous; chickpeas (garbanzos),...        2209252.0
# 4      Vegetables, leguminous; chickpeas (garbanzos),...         212964.0
# ...                                                  ...              ...
# 76706  Chickpeas (garbanzos), dried, shelled, whether...         693291.0
# 76707  Chickpeas (garbanzos), dried, shelled, whether...         389245.0
# 76708  Chickpeas (garbanzos), dried, shelled, whether...        8565611.0
# 76709  Chickpeas (garbanzos), dried, shelled, whether...          18365.0
# 76710  Chickpeas (garbanzos), dried, shelled, whether...        4418503.0
#
# [27291 rows x 10 columns]

# %%
df1['trade_value_usd'] = df1['trade_value_usd'] / 1000000
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# Python: sorting and aggregations
df_agg = df1.sort_values(by=['reporter_iso','year'], ascending = [True, True]).groupby(['reporter_iso','year',]).agg(
    first_value =  ('trade_value_usd', 'first'),
    last_value =  ('trade_value_usd', 'last'),
    total =  ('trade_value_usd', sum),
    promedio = ('trade_value_usd', 'mean'))

# %%
df_agg['var_impo'] = ((df_agg['last_value'] / df_agg['first_value'])-1) * 100

# %%
#Calculo mediana
mediana = df_agg['promedio'].median()
mediana
#Nueva columna (feature, variable), si promedio de importaciones (totales) es mayor a la Mediana
df_agg['mayor_mediana'] = np.where(df_agg['promedio'] < mediana, "NO", "SI")

# %%
#Nueva columna (feature, variable), si promedio de importaciones (totales) es mayor a la Mediana
df_agg['mayor_mediana'] = np.where(df_agg['promedio'] < mediana, "NO", "SI")

# %%
UE = ["USA","DEU","AUT","BEL","BGR","CYP","HRV","DNK","SVK","SVN","ESP","EST",
      "FIN","FRA","GRC","HUN","IRL","ITA","LVA","LTU","LUX","MLT","MCO","NLD",
      "POL","PRT","GBR","CZE","ROU","SMR","SWE"]

# %%
# Genero columna de partners con partner_iso
result = []
for value in df1['partner_iso']:
  if value == "ARG":
    result.append("ARG")
  elif value == "CHN":
    result.append("CHN")
  elif value in UE:
    result.append("UE")
  else:
    result.append("Resto")
   
df1["procedencia"] = result
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
# i) Creo df de totales y ii) desagregago por partners (totales y media)
df_salud_proc = df1.sort_values(by=['reporter_iso'], ascending = [True]).groupby(['reporter_iso']).agg(total =  ('trade_value_usd', sum),
                                                                                                    media_value = ('trade_value_usd', 'mean'),
                                                                                                    first = ('trade_value_usd', 'first'),
                                                                                                    last =('trade_value_usd', 'last'),
                                                                                                    last_year = ('year', 'last'))

df_salud_proc2 = df1.sort_values(by=['reporter_iso'], ascending = [True]).groupby(['reporter_iso','procedencia']).agg(total =  ('trade_value_usd', sum),
                                                                                                                   media =('trade_value_usd', 'mean'),
                                                                                                                   first = ('trade_value_usd', 'first'),
                                                                                                                   last =('trade_value_usd', 'last'))

df_salud_proc2 = df_salud_proc2.unstack()

df_salud_proc2.columns = ['ARG_sum','UE_sum','CHN_sum','Resto_sum',
                          'ARG_media','UE_media','CHN_media','Resto_media',
                          'ARG_first','UE_first','CHN_first','Resto_first',
                          'ARG_last','UE_last','CHN_last','Resto_last']
# Merge i) y ii)
df_salud_proc3 = pd.merge(df_salud_proc, df_salud_proc2, left_index=True, right_index=True)

#Calculo participacion de cada partner por iso_pais
df_salud_proc3['ARG_part'] = (df_salud_proc3['ARG_sum'] / df_salud_proc3['total'])*100  
df_salud_proc3['UE_part'] = (df_salud_proc3['UE_sum'] / df_salud_proc3['total'])*100  
df_salud_proc3['CHN_part'] = (df_salud_proc3['CHN_sum'] / df_salud_proc3['total'])*100  
df_salud_proc3['Resto_part'] = (df_salud_proc3['Resto_sum'] / df_salud_proc3['total'])*100  

#Calculo variaciones de importaciones para el iso_pais, mediana, y si el pais está encima o debajo de la mediana
df_salud_proc3['var_impo'] = ((df_salud_proc3['last'] / df_salud_proc['first'])-1)*100

mediana = df_salud_proc3['media_value'].median()
df_salud_proc3['mayor_median'] = np.where(
    df_salud_proc['media_value'] < mediana, "NO", "SI")

# %%
df_salud_proc3 = df_salud_proc3.reset_index()

# %%
df_salud_proc3['ARG_part'] = df_salud_proc3['ARG_part'].fillna(0).astype(int)

impo_global = df_salud_proc3[['reporter_iso','total', 'media_value', 'ARG_part', 'UE_part', 'CHN_part', 'Resto_part', 'last_year']]
impo_global = impo_global.round(2)
#impo_global.columns = ['Total', 'Mean', 'Part. Arg', 'Part. UE', 'Part. China', 'Part. Rest', 'Last Year' ]

# %%
impo_global = impo_global.reset_index()

# %%
filename = '/content/drive/My Drive/Agencia/equipamiento_medico/cod_paises.csv' 
f = open(filename, "r")
cod_paises = pd.read_csv(filename, sep=',', encoding= 'unicode_escape')

# %%
cod_paises.columns = ['reporter_iso','continente','reporter','zona']

# %%
#Merge entre base con el listado de codigos de paises
df_salud_proced = pd.merge(df_salud_proc3, cod_paises, on = 'reporter_iso')

# %%
#Fillna para conservar la variable ARG_part y no excluir tantos paises en el PCA
df_salud_proced[['ARG_sum','ARG_media','ARG_first','ARG_part','ARG_last']] = df_salud_proced[['ARG_sum','ARG_media','ARG_first','ARG_part','ARG_last']].fillna(0).astype(int)

# %%
df_salud_proced.shape
# Out:
# (169, 31)

# %%
#Guardo como CSV
df_salud_proced.to_csv("/content/drive/MyDrive/Agencia/molineria/df_salud_proced.csv", index=False)

# %% [markdown]
# #**CLUSTERIZACIÓN**
#
# ---
#
#
#
# ---

# %%
#Import economic, demografic and health spending (public & private) (World Bank Data Base)
filename = '/content/drive/My Drive/Agencia/maquinaria/dbs/variables.xlsx' 
filename1 = '/content/drive/My Drive/Agencia/molineria/indicadores/indicadores.csv' 
f = open(filename, "r")
data_gral = pd.read_excel(filename)#, sep=',', encoding= 'unicode_escape')
index_molineria = pd.read_csv(filename1)

# %%
#Impute NaN with zeros
#data_gral['C2'] = data_gral['C2'].replace(0, np.nan)
#data_gral['S7'] = data_gral['S7'].fillna(0).astype(int)

# %%
#Rename columns
#data_gral.columns = ['reporter', 'reporter_iso', 'D1', 'D3', 'D7', 'E3', 'E5', 'C2',
#       'C4', 'S3', 'S5', 'S7', 'G1', 'G7', 'G8']

# %%
data_gral.columns = ['reporter_iso', 'agro_land', 'ied', 'idl', 'x_pbi', 'm_pbi', 'agro_pbi',
       'pbi_growth', 'tasa_min']

# %%
data_gral = data_gral[['reporter_iso', 'idl', 'x_pbi', 'm_pbi',
       'pbi_growth', 'tasa_min']]

# %%
data_gral = pd.merge(data_gral, index_molineria, on = 'reporter_iso', how = 'inner')

# %%
df_salud_proced.columns
# Out:
# Index(['reporter_iso', 'total', 'media_value', 'first', 'last', 'last_year',
#        'ARG_sum', 'UE_sum', 'CHN_sum', 'Resto_sum', 'ARG_media', 'UE_media',
#        'CHN_media', 'Resto_media', 'ARG_first', 'UE_first', 'CHN_first',
#        'Resto_first', 'ARG_last', 'UE_last', 'CHN_last', 'Resto_last',
#        'ARG_part', 'UE_part', 'CHN_part', 'Resto_part', 'var_impo',
#        'mayor_median', 'continente', 'reporter', 'zona'],
#       dtype='object')

# %%
#Select columns from imports dataframe
df_salud_sub = df_salud_proced[['media_value', 'ARG_part', 'UE_part','CHN_part','reporter_iso']]

#Merge
df_cluster_vf = pd.merge(data_gral, df_salud_sub, on = 'reporter_iso', how = 'inner')

# %%
df_cluster_vf = df_cluster_vf.drop(['reporter', 'continente', 'zona'], 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
#Drop NaN (sine qua non condition to apply PCA)
data_pc = df_cluster_vf.dropna()
data_pc = data_pc.set_index('reporter_iso')

# %%
data_pc.head(1)
# Out:
#                idl  x_pbi  m_pbi  pbi_growth  tasa_min    D1      D2     D3  \
# reporter_iso
# AFG           1.95    0.0    0.0     1.53141       6.5  41.6  2141.8  337.0
#
#                 D4     D5     D6  media_value  ARG_part  UE_part   CHN_part
# reporter_iso
# AFG           33.0  76.25  92.42    39.141685         0  0.00738  99.976318

# %%
#Subset PCA
data_pc_slice = data_pc.iloc[:,0:15]
columns_slice = data_pc_slice.columns
data_pc_slice = data_pc_slice.astype(float)
data_pc_slice.shape
# Out:
# (133, 15)

# %%
#Preprossecing data
#data_x = preprocessing.scale(data_pc_slice)
#data_x = pd.DataFrame(data_x, columns = columns_slice)

data_x = preprocessing.StandardScaler().fit_transform(data_pc_slice)
data_x = pd.DataFrame(data_x, columns = columns_slice)

# %%
#PRINCIPAL COMPONENTS ANALYSIS
pca = decomposition.PCA(n_components=5)
pca.fit(data_x)
comp = pca.transform(data_x)
comp_df = pd.DataFrame(comp, columns=['PC1', 'PC2', 'PC3','PC4', 'PC5'])

# %%
#Dataframa WB variables, Imports and PCs
df_slice_comp = pd.merge(data_x, comp_df, left_index=True, right_index=True)

# %%
#KMEANS CLUSTERING
kmean = KMeans(n_clusters = 5, max_iter = 10000, n_init = 50)
kmean.fit(comp)
# Out:
# KMeans(max_iter=10000, n_clusters=5, n_init=50)

# %%
#Cluster identification
#kMEANS labels to dataframe
clusters = kmean.labels_
clusters = pd.DataFrame(clusters, columns = ['cluster'])

#iso codes 
data_pc = data_pc_slice.reset_index() 

#Unir iso_pais, con df_slice_comp y cluster
df_vf = pd.merge(data_pc, comp_df, left_index=True, right_index=True)
df_vf = pd.merge(df_vf, clusters, left_index=True, right_index=True)

#Select columns
features = df_vf.columns[1:-6]

# %%
df_vf.head()
# Out:
#   reporter_iso   idl      x_pbi      m_pbi  pbi_growth  tasa_min     D1  \
# 0          AFG  1.95   0.000000   0.000000    1.531410    6.5000   41.6
# 1          AGO  2.05  35.019373  25.620855   -2.151105    9.8425   42.1
# 2          ALB  2.66  29.307644  44.106203    1.858918    3.7240   38.4
# 3          ARE  3.96  97.622402  72.171329    0.764932    4.9940  100.0
# 4          ARG  2.89  14.514365  14.387358   -2.760085   13.3940 -165.8
#
#        D2     D3     D4  ...  media_value  ARG_part   UE_part   CHN_part  \
# 0  2141.8  337.0   33.0  ...    39.141685       0.0  0.007380  99.976318
# 1  2109.2    7.0   45.0  ...     4.318538       1.0  0.216678  75.588264
# 2  2488.4   21.5  161.0  ...     2.066500       2.0  0.013263  78.817878
# 3  2665.8    5.0   23.0  ...     3.113383       6.0  0.239081  76.982482
# 4  2413.0    5.0  346.0  ...    46.090525       0.0  0.211158  93.796315
#
#         PC1       PC2       PC3       PC4       PC5  cluster
# 0 -4.661944  1.114492 -1.530112 -1.056156 -0.379538        0
# 1 -1.747438  0.899880 -0.274143  0.246447 -0.873075        0
# 2  0.340149  0.963165  0.002768  0.993352 -1.454463        1
# 3  2.282177  2.106500  1.021072  1.879151  0.136087        2
# 4 -0.055363 -2.006768 -1.288513 -0.846370 -2.159232        3
#
# [5 rows x 22 columns]

# %%
features
# Out:
# Index(['idl', 'x_pbi', 'm_pbi', 'pbi_growth', 'tasa_min', 'D1', 'D2', 'D3',
#        'D4', 'D5', 'D6', 'media_value', 'ARG_part', 'UE_part', 'CHN_part'],
#       dtype='object')

# %%
#Loadings matrix: correlation matrix
loadings_matrix = pd.DataFrame(pca.components_.T, columns=['PC1', 'PC2','PC3','PC4', 'PC5'], index=features)
loadings_matrix = loadings_matrix.reset_index()
loadings_matrix.columns = ['Referencia', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5'] 
#loadings_matrix = loadings_matrix.astype(str)

#Variables description
variables = {
    'Referencia': ['idl', 'x_pbi', 'm_pbi', 'pbi_growth','tasa_min', 'D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'media_value', 'ARG_part', 'UE_part', 'CHN_part'],
    'Descripción': ['Índice de Desempeño Logístico','Exportaciones de bienes y servicios (% del PIB)', 'Importaciones de bienes y servicios (% del PIB)', 'Crecimiento del PIB (% anual)', 
                    'Tasa mínima arancelaria (%)', 'Coeficiente de dependencia de las importaciones de cereales (%)', 'Requerimiento promedio de energía alimentaria (kcal/cap/día)',
                    'Valor de las importaciones de alimentos respecto de las exportaciones totales de mercancías (%)','Valor medio de la producción de alimentos (I$ constante por persona)',
                    'Variabilidad del suministro de alimentos per cápita (kcal/persona/día)', 'Índice produccion bruto p.c. alimentos y ganado',
                    'Importaciones promedio 2017-2021','Participación argentina en importaciones', 'Participación UE en importaciones', 'Participación china en importaciones'
                    ]
}

variables = pd.DataFrame(variables)

#Merge loadings and variables descriptions
loadings_matrix_detalle = pd.merge(loadings_matrix, variables, on = 'Referencia')

# %% [markdown]
# #***PLOTS***
#
# ---
#
#
#
# ---

# %%
df_vf = pd.merge(df_vf, cod_paises, on = 'reporter_iso', how = 'inner')

# %%
df_vf.iloc[:, 1:20] = df_vf.iloc[:, 1:20].round(2) # Remember that Python does not slice inclusive of the ending index.

# %%
df_vf.reporter = df_vf.reporter.replace('Reino Unido de Gran Bretaña e Irlanda del Norte', 'Reino Unido')

# %%
# PCA and Clusters Scatter Plot


fig = px.scatter(df_vf, x=df_vf['PC1'], y=df_vf['PC2'], color=df_vf['cluster'],hover_data = ['reporter_iso', 'reporter','media_value', 'ARG_part', 'UE_part','CHN_part'], color_discrete_sequence=["green", "blue", "yellow", "magenta", "black"],
                 labels={'PC1': 'Componente Principal #1', 'PC2':'Componente Principal #2'})

py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2f51fe06-0aeb-4bd8-9f1e-2516d9b27e50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f51fe06-0aeb-4bd8-9f1e-2516d9b27e50")) {                    Plotly.newPlot(                        "2f51fe06-0aeb-4bd8-9f1e-2516d9b27e50",                        [{"customdata":[["AFG","Afganist\u00e1n",39.14,0.0,0.01,99.98],["AGO","Angola",4.32,1.0,0.22,75.59],["ALB","Albania",2.07,2.0,0.01,78.82],["ARE","Emiratos \u00c1rabes Unidos",3.11,6.0,0.24,76.98],["ARG","Argentina",46.09,0.0,0.21,93.8],["ARM","Armenia",0.8,0.0,0.16,84.68],["ATG","Antigua y Barbuda",0.21,0.0,0.03,84.91],["AUS","Australia",5.18,18.0,1.33,63.5],["AUT","Austria",4.49,0.0,0.22,59.99],["AZE","Azerbaiy\u00e1n",1.44,4.0,0.05,91.83],["BEL","B\u00e9lgica",10.27,1.0,0.48,57.76],["BEN","Benin",1.12,0.0,0.07,94.07],["BFA","Burkina Faso",0.77,0.0,0.12,95.75],["BGR","Bulgaria",1.58,0.0,3.07,57.21],["BHS","Bahamas",0.63,0.0,0.01,56.98],["BIH","Bosnia y Herzegovina",1.77,0.0,0.06,81.66],["BLR","Belar\u00fas",7.01,5.0,0.43,89.73],["BLZ","Belice",0.75,0.0,0.01,75.47],["BRA","Brasil",13.65,13.0,3.17,73.78],["BRB","Barbados",0.51,0.0,0.03,66.3],["BWA","Botswana",2.32,0.0,0.0,99.42],["CAN","Canad\u00e1",6.8,0.0,1.16,54.66],["CHE","Suiza",2.08,0.0,0.93,59.7],["CHL","Chile",8.16,26.0,0.59,64.3],["CHN","China",478.35,3.0,0.0,82.65],["CIV","C\u00f4te d'Ivoire",1.11,16.0,0.11,57.06],["CMR","Camer\u00fan",0.58,22.0,0.1,56.96],["COG","Congo",0.49,0.0,0.04,70.61],["COL","Colombia",28.3,2.0,0.35,55.96],["CPV","Cabo Verde",0.42,12.0,0.09,56.77],["CRI","Costa Rica",6.9,0.0,0.46,60.51],["CYP","Chipre",1.42,9.0,0.04,58.99],["DEU","Alemania",18.36,0.0,1.23,63.31],["DNK","Dinamarca",5.58,7.0,2.3,57.46],["DOM","Rep\u00fablica Dominicana",6.18,2.0,0.18,66.77],["DZA","Argelia",26.47,24.0,0.01,69.66],["ECU","Ecuador",15.72,6.0,0.22,79.02],["EGY","Egipto",45.66,9.0,0.14,82.31],["ESP","Espa\u00f1a",22.22,5.0,0.23,74.77],["EST","Estonia",0.67,0.0,0.35,57.51],["ETH","Etiop\u00eda",3.85,0.0,0.04,67.18],["FIN","Finlandia",1.83,0.0,1.79,59.58],["FJI","Fiji",0.45,0.0,0.08,99.02],["FRA","Francia",9.95,1.0,0.38,66.08],["GBR","Reino Unido",12.43,6.0,1.41,62.93],["GEO","Georgia",0.82,0.0,0.11,89.9],["GHA","Ghana",0.77,12.0,0.51,73.32],["GIN","Guinea",0.88,0.0,0.13,77.02],["GMB","Gambia",0.4,3.0,0.3,82.11],["GRC","Grecia",4.48,7.0,0.33,67.89],["GRD","Granada",0.1,0.0,0.01,80.19],["GRL","Dinamarca",0.1,0.0,0.16,50.4],["GTM","Guatemala",8.03,0.0,0.25,62.29],["GUY","Guyana",0.54,0.0,0.01,71.57],["HND","Honduras",5.3,0.0,0.08,64.66],["HRV","Croacia",2.33,0.0,0.18,54.88],["HUN","Hungr\u00eda",3.7,0.0,0.09,57.46],["IDN","Indonesia",32.73,11.0,0.5,63.68],["IND","India",13.38,0.0,1.89,94.22],["IRL","Irlanda",6.72,7.0,0.32,62.34],["ISL","Islandia",0.68,0.0,0.33,70.45],["ISR","Israel",6.56,0.0,0.63,78.31],["ITA","Italia",19.62,5.0,0.44,68.98],["JAM","Jamaica",2.17,0.0,0.04,58.28],["JOR","Jordania",5.33,17.0,0.29,64.65],["JPN","Jap\u00f3n",56.79,0.0,3.5,64.61],["KAZ","Kazajst\u00e1n",1.92,2.0,0.31,92.66],["KEN","Kenya",1.69,0.0,0.39,94.09],["KGZ","Kirguist\u00e1n",0.93,0.0,0.16,97.07],["KHM","Camboya",2.54,5.0,1.08,88.15],["KWT","Kuwait",1.02,8.0,0.13,79.25],["LBN","L\u00edbano",2.9,8.0,0.2,78.43],["LCA","Santa Luc\u00eda",0.36,0.0,0.01,91.68],["LKA","Sri Lanka",2.03,0.0,1.01,78.8],["LSO","Lesotho",2.57,0.0,0.0,99.13],["LTU","Lituania",1.91,3.0,0.89,57.67],["LUX","Luxemburgo",0.79,0.0,0.34,52.54],["LVA","Letonia",1.45,1.0,0.13,58.44],["MAR","Marruecos",11.12,14.0,0.15,69.74],["MDG","Madagascar",1.94,1.0,0.31,89.69],["MEX","M\u00e9xico",167.23,0.0,0.14,51.8],["MLI","Mal\u00ed",0.46,2.0,0.5,74.18],["MLT","Malta",0.65,1.0,0.1,54.1],["MMR","Myanmar",2.71,0.0,1.45,81.21],["MNE","Montenegro",0.51,0.0,0.07,93.69],["MNG","Mongolia",0.41,0.0,5.8,9 ...

# %%
df_comp = df_vf[['PC1', 'PC2', 'PC3', 'PC4', 'PC5','reporter', 'cluster']]

# %%
df_vf.reporter = df_vf.reporter.replace('Hong Kong (región administrativa especial de China)', 'Hong Kong')
df_vf.reporter = df_vf.reporter.replace('Macao (región administrativa especial de China)', 'Macao')

# %%
# Top 20 reporters. Anual Mean 2017-2021
df = df_vf
sd = df.nlargest(20,'media_value')
fd = sd.sort_values(by='media_value', ascending = True)

fig = px.bar(fd, x="media_value", y="reporter", orientation='h',
             hover_data=['reporter_iso','media_value', 'ARG_part', 'UE_part','CHN_part'],
             height=600,
             title='Principales importadores a nivel global: top 20 importadores. Promedio anual 2016-2020',
             labels={'media_value': 'Importaciones (millones USD)', 'reporter':'País'})
fig.show()
py.iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e2a65ee3-32fe-4cdf-98ee-5142d1e6fe6b" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2a65ee3-32fe-4cdf-98ee-5142d1e6fe6b")) {                    Plotly.newPlot(                        "e2a65ee3-32fe-4cdf-98ee-5142d1e6fe6b",                        [{"alignmentgroup":"True","customdata":[["PHL",6.0,1.46,62.63],["SAU",12.0,0.16,67.63],["ECU",6.0,0.22,79.02],["NLD",1.0,1.0,71.01],["DEU",0.0,1.23,63.31],["PER",8.0,0.38,68.04],["ITA",5.0,0.44,68.98],["TUR",5.0,0.21,87.07],["ESP",5.0,0.23,74.77],["THA",2.0,0.64,81.54],["DZA",24.0,0.01,69.66],["COL",2.0,0.35,55.96],["IDN",11.0,0.5,63.68],["AFG",0.0,0.01,99.98],["VNM",21.0,1.52,66.88],["EGY",9.0,0.14,82.31],["ARG",0.0,0.21,93.8],["JPN",0.0,3.5,64.61],["MEX",0.0,0.14,51.8],["CHN",3.0,0.0,82.65]],"hovertemplate":"Importaciones (millones USD)=%{x}<br>Pa\u00eds=%{y}<br>reporter_iso=%{customdata[0]}<br>ARG_part=%{customdata[1]}<br>UE_part=%{customdata[2]}<br>CHN_part=%{customdata[3]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[13.69,14.28,15.72,15.95,18.36,19.14,19.62,21.9,22.22,22.51,26.47,28.3,32.73,39.14,43.09,45.66,46.09,56.79,167.23,478.35],"xaxis":"x","y":["Filipinas","Arabia Saudita","Ecuador","Pa\u00edses Bajos","Alemania","Per\u00fa","Italia","Turqu\u00eda","Espa\u00f1a","Tailandia","Argelia","Colombia","Indonesia","Afganist\u00e1n","Viet Nam","Egipto","Argentina","Jap\u00f3n","M\u00e9xico","China"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201 ...
#         <iframe
#             width="100%"
#             height="600px"
#             src="https://plotly.com/~gabriel.fernandez/737.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
#LATAM imports. Anual Mean 2016-2020 

latam = ['ARG','ABW','BHS','BRB','BLZ','BMU','BOL','BRA','CHL','COL','CRI','CUB','ECU','SLV','GTM',
         'GUF','GUY','HTI','HND','FLK','JAM','MEX','NIC','PAN','PRY','PER','PRI','DOM','SUR','TTO',
         'URY','VEN']

df = df_salud_proced.loc[df_salud_proced['reporter_iso'].isin(latam)]
sd = df.nlargest(20,'media_value')
fd = sd.sort_values(by='media_value', ascending = True)

fig = px.bar(fd, x="media_value", y="reporter", orientation='h',
             hover_data=['reporter_iso','media_value', 'ARG_part', 'UE_part','CHN_part'],
             height=600,
             title='Importaciones de Latinoamérica. Promedio anual 2016-2020',
             labels={'media_value': 'Importaciones (millones USD)', 'reporter':'País'})


py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="435e7d98-b576-46ce-8740-71756d0eebe5" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("435e7d98-b576-46ce-8740-71756d0eebe5")) {                    Plotly.newPlot(                        "435e7d98-b576-46ce-8740-71756d0eebe5",                        [{"alignmentgroup":"True","customdata":[["BHS",0,0.008209558009362046,56.97769393595541],["BLZ",0,0.0062775404471469304,75.46714197474874],["URY",17,0.1544016822259254,79.59297352621522],["JAM",0,0.04332085096411294,58.27742481703708],["PRY",11,0.31968368159046356,85.91942772527624],["PAN",0,0.3385956509894524,65.93085434788671],["NIC",0,0.008090085921873661,76.92464781900836],["BOL",41,0.480658105707243,56.18687355505637],["SLV",0,0.10493260115997584,67.89801195808786],["HND",0,0.08280000810641557,64.65789024276165],["DOM",2,0.18047049123539222,66.77045971500668],["CRI",0,0.462345946282648,60.51355781143929],["GTM",0,0.24581157405941478,62.29068505954146],["CHL",26,0.5935063911208058,64.29931845675816],["BRA",13,3.1695569252030826,73.77754041741117],["ECU",6,0.21859427008668647,79.01538456986968],["PER",8,0.3821893615225471,68.03689754528295],["COL",2,0.3463409368665168,55.95804099272181],["ARG",0,0.2111583085543588,93.7963147867309],["MEX",0,0.14344635353460025,51.80000686407528]],"hovertemplate":"Importaciones (millones USD)=%{x}<br>Pa\u00eds=%{y}<br>reporter_iso=%{customdata[0]}<br>ARG_part=%{customdata[1]}<br>UE_part=%{customdata[2]}<br>CHN_part=%{customdata[3]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[0.6298470786290323,0.7504163884615385,2.1497591423699913,2.168614423111111,2.183822234620887,3.1527092982456137,3.9268326446518302,3.9754589169675087,5.152485334396936,5.304421053925456,6.179719054945055,6.895932060821085,8.032982440697674,8.164537510173094,13.651058941176471,15.724524358732875,19.144479250140527,28.297761074257426,46.09052516078432,167.2254504210526],"xaxis":"x","y":["Bahamas","Belice","Uruguay","Jamaica","Paraguay","Panam\u00e1","Nicaragua","Bolivia","El Salvador","Honduras","Rep\u00fablica Dominicana","Costa Rica","Guatemala","Chile","Brasil","Ecuador","Per\u00fa","Colombia","Argentina","M\u00e9xico"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666 ...

# %%
#Argentina imports. Anual Mean 2016-2020 

# SLICING & GROUPING
imp_arg = df1[df1['partner_iso'] == 'ARG']
imp_arg = imp_arg.groupby(['reporter']).agg(total =  ('trade_value_usd', sum),
                                                          media_value =('trade_value_usd', 'mean'),
                                                          first = ('trade_value_usd', 'first'),last =('trade_value_usd', 'last'), last_year = ('year','last'))
imp_arg = imp_arg.reset_index()

imp_arg.reporter = imp_arg.reporter.replace('Bolivia (Plurinational State of)', 'Bolivia')

df = imp_arg
sd = df.nlargest(15,'media_value')
fd = sd.sort_values(by='media_value', ascending = True)

fig = px.bar(fd, x="media_value", y="reporter", orientation='h',
             hover_data=['reporter','media_value', 'first', 'last','last_year'],
             height=600,
             title='A qué países le exporta Argentina? Top 15 importadores. Promedio anual 2016-2020',
             labels={'media_value': 'Importaciones (millones USD)', 'reporter':'País'})

py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5f8551ca-5c91-480f-afaf-8eda9b2f12dc" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f8551ca-5c91-480f-afaf-8eda9b2f12dc")) {                    Plotly.newPlot(                        "5f8551ca-5c91-480f-afaf-8eda9b2f12dc",                        [{"alignmentgroup":"True","customdata":[[8.895092,624.851738,2016.0],[0.0276,0.029798,2016.0],[35.071455,298.85902,2016.0],[16.127202,515.947316,2016.0],[0.264109,2.444981,2016.0],[226.128254,134.721461,2016.0],[5.435043,366.630823,2016.0],[0.535467,0.835625,2020.0],[1.034859,556.168806,2016.0],[0.000112,0.423054,2016.0],[1.706335,0.038012,2020.0],[2.209252,511.934735,2016.0],[0.594261,0.218721,2016.0],[0.011023,9.001771,2017.0],[2683.448515,0.041764,2020.0]],"hovertemplate":"Importaciones (millones USD)=%{x}<br>Pa\u00eds=%{y}<br>first=%{customdata[0]}<br>last=%{customdata[1]}<br>last_year=%{customdata[2]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[47.273039374999996,50.7500048255814,64.5588262,67.65926378409091,72.61850702173913,72.88945004347826,73.94271587323944,76.2967562027027,82.59535548484848,87.14406459574468,131.17439811111112,175.79529426086955,184.61616662711864,335.546753025641,982.4711124716981],"xaxis":"x","y":["Spain","Rep. of Korea","Turkey","Italy","Australia","Morocco","United Kingdom","Saudi Arabia","Poland","Malaysia","Egypt","Algeria","Indonesia","Viet Nam","China"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333 ...

# %%
#Loadings matrix to Table
df = loadings_matrix
df[['PC1', 'PC2', 'PC3', 'PC4', 'PC5']] = df[['PC1', 'PC2', 'PC3', 'PC4', 'PC5']].round(3) 

fig = go.Figure(data=[go.Table(
    columnorder = [1,2,3,4,5,6],
    columnwidth = [110, 80, 80, 80, 80, 80],
    header=dict(values=list(df.columns),
                fill_color='rgba(92,140,164)',
                align='center'),
    cells=dict(values=[df.Referencia, df.PC1, df.PC2, df.PC3, df.PC4, df.PC5],
               fill_color='rgba(196,196,196)',
               align='center'))
])
py.iplot(fig)
#fig.show()
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~gabriel.fernandez/572.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
#Variables description to Table
df = variables 
fig = go.Figure(data=[go.Table(
    columnorder = [1,2],
    columnwidth = [80, 200],
    header=dict(values=list(df.columns),
                fill_color='rgba(92,140,164)',
                align='center'),
    cells=dict(values=[df.Referencia, df.Descripción],
               fill_color='rgba(196,196,196)',
               align='center'))
])
py.iplot(fig)
#fig.show()
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~gabriel.fernandez/743.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
df2 = pd.merge(impo_global, cod_paises, on = 'reporter_iso', how = 'inner')
df2.reporter = df2.reporter.replace('Reino Unido de Gran Bretaña e Irlanda del Norte', 'Reino Unido')

# %%
df2 = df2.set_index('index')
df2 = df2[['reporter', 'total', 'media_value', 'ARG_part', 'UE_part','CHN_part', 'Resto_part', 'last_year']]
df2=df2.rename(columns = {'total':'total (Mill.)'})

# %%
#Imports general data

fig = go.Figure(data=[go.Table(
    columnorder = [1,2,3,4,5,6,7,8],
    columnwidth = [110, 80, 80, 80, 80, 80, 80],
    header=dict(values=list(df2.columns),
                fill_color='rgba(92,140,164)',
                align='center'),
    cells=dict(values= [df2.reporter, df2['total (Mill.)'], df2.media_value, df2.ARG_part, df2.UE_part, df2.CHN_part, df2.Resto_part, df2.last_year],
               fill_color='rgba(196,196,196)',
               align='center'))
])
py.iplot(fig)
#fig.show()
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~gabriel.fernandez/560.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# RANKING PC1
df = df_vf
sd = df.nlargest(20,'PC1')
fd = sd.sort_values(by='PC1', ascending = True)

fig = px.bar(fd, x="PC1", y="reporter", orientation='h',
             hover_data=['reporter_iso','media_value', 'ARG_part', 'UE_part','CHN_part'],
             height=600,
             title='Top 20 Ranking de países según PC1',
             labels={'PC1': 'Componente Principal #1', 'reporter':'País'})

py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fcb6e4d5-fabb-40e9-a21f-fa62dafc4502" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fcb6e4d5-fabb-40e9-a21f-fa62dafc4502")) {                    Plotly.newPlot(                        "fcb6e4d5-fabb-40e9-a21f-fa62dafc4502",                        [{"alignmentgroup":"True","customdata":[["POL",9.97,12.0,0.57,61.4],["AUT",4.49,0.0,0.22,59.99],["LVA",1.45,1.0,0.13,58.44],["VNM",43.09,21.0,1.52,66.88],["CAN",6.8,0.0,1.16,54.66],["ARE",3.11,6.0,0.24,76.98],["AUS",5.18,18.0,1.33,63.5],["BEL",10.27,1.0,0.48,57.76],["SVK",1.71,0.0,0.37,60.58],["HUN",3.7,0.0,0.09,57.46],["NLD",15.95,1.0,1.0,71.01],["BGR",1.58,0.0,3.07,57.21],["UKR",1.95,0.0,4.12,54.85],["LTU",1.91,3.0,0.89,57.67],["NZL",2.49,12.0,0.79,74.39],["DNK",5.58,7.0,2.3,57.46],["EST",0.67,0.0,0.35,57.51],["MLT",0.65,1.0,0.1,54.1],["IRL",6.72,7.0,0.32,62.34],["LUX",0.79,0.0,0.34,52.54]],"hovertemplate":"Componente Principal #1=%{x}<br>Pa\u00eds=%{y}<br>reporter_iso=%{customdata[0]}<br>media_value=%{customdata[1]}<br>ARG_part=%{customdata[2]}<br>UE_part=%{customdata[3]}<br>CHN_part=%{customdata[4]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[2.04,2.06,2.15,2.22,2.27,2.28,2.46,2.77,2.81,2.91,2.95,2.95,3.0,3.14,3.16,3.28,3.4,3.61,3.93,5.73],"xaxis":"x","y":["Polonia","Austria","Letonia","Viet Nam","Canad\u00e1","Emiratos \u00c1rabes Unidos","Australia","B\u00e9lgica","Eslovaquia","Hungr\u00eda","Pa\u00edses Bajos","Bulgaria","Ucrania","Lituania","Nueva Zelandia","Dinamarca","Estonia","Malta","Irlanda","Luxemburgo"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar" ...

# %%
# Cluster #1 imports. Annual Mean 2016-2020
df = df_vf.loc[df_vf['cluster'].isin([0])]
sd = df.nlargest(20,'media_value')
fd = sd.sort_values(by='media_value', ascending = True)


fig = px.bar(fd, x="media_value", y="reporter", orientation='h',
             hover_data=['reporter_iso','media_value', 'ARG_part', 'UE_part','CHN_part'],
             height=600,
             title='Top 20 Importaciones de países Cluster #1. Promedio anual 2016-2020',
             labels={'media_value': 'Importaciones (millones USD)', 'reporter':'País'})

py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3623f8ed-2310-4c6b-b2db-3af423b89ddf" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3623f8ed-2310-4c6b-b2db-3af423b89ddf")) {                    Plotly.newPlot(                        "3623f8ed-2310-4c6b-b2db-3af423b89ddf",                        [{"alignmentgroup":"True","customdata":[["GMB",3.0,0.3,82.11],["CPV",12.0,0.09,56.77],["FJI",0.0,0.08,99.02],["MNE",0.0,0.07,93.69],["BRB",0.0,0.03,66.3],["SUR",0.0,0.02,65.64],["BHS",0.0,0.01,56.98],["BLZ",0.0,0.01,75.47],["MOZ",0.0,0.09,96.9],["NAM",0.0,0.04,98.25],["AZE",4.0,0.05,91.83],["BWA",0.0,0.0,99.42],["LSO",0.0,0.0,99.13],["LBN",8.0,0.2,78.43],["NIC",0.0,0.01,76.92],["AGO",1.0,0.22,75.59],["ZWE",0.0,0.01,93.93],["YEM",12.0,0.11,82.17],["ECU",6.0,0.22,79.02],["AFG",0.0,0.01,99.98]],"hovertemplate":"Importaciones (millones USD)=%{x}<br>Pa\u00eds=%{y}<br>reporter_iso=%{customdata[0]}<br>ARG_part=%{customdata[1]}<br>UE_part=%{customdata[2]}<br>CHN_part=%{customdata[3]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[0.4,0.42,0.45,0.51,0.51,0.6,0.63,0.75,1.14,1.36,1.44,2.32,2.57,2.9,3.93,4.32,6.28,8.58,15.72,39.14],"xaxis":"x","y":["Gambia","Cabo Verde","Fiji","Montenegro","Barbados","Suriname","Bahamas","Belice","Mozambique","Namibia","Azerbaiy\u00e1n","Botswana","Lesotho","L\u00edbano","Nicaragua","Angola","Zimbabwe","Yemen","Ecuador","Afganist\u00e1n"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444 ...

# %%
# Cluster #2 imports. Annual Mean 2016-2020
df = df_vf.loc[df_vf['cluster'].isin([1])]
sd = df.nlargest(20,'media_value')
fd = sd.sort_values(by='media_value', ascending = True)


fig = px.bar(fd, x="media_value", y="reporter", orientation='h',
             hover_data=['reporter_iso','media_value', 'ARG_part', 'UE_part','CHN_part'],
             height=600,
             title='Top 20 Importaciones de países Cluster #2. Promedio anual 2016-2020',
             labels={'media_value': 'Importaciones (millones USD)', 'reporter':'País'})

py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4230f3c1-0e5a-4974-a686-10df9bb2cd42" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4230f3c1-0e5a-4974-a686-10df9bb2cd42")) {                    Plotly.newPlot(                        "4230f3c1-0e5a-4974-a686-10df9bb2cd42",                        [{"alignmentgroup":"True","customdata":[["SLV",0.0,0.1,67.9],["HND",0.0,0.08,64.66],["JOR",17.0,0.29,64.65],["DOM",2.0,0.18,66.77],["ISR",0.0,0.63,78.31],["CRI",0.0,0.46,60.51],["BLR",5.0,0.43,89.73],["CHL",26.0,0.59,64.3],["MYS",21.0,1.23,68.94],["POL",12.0,0.57,61.4],["MAR",14.0,0.15,69.74],["PRT",0.0,0.04,71.54],["GBR",6.0,1.41,62.93],["TUN",2.0,0.06,71.66],["SAU",12.0,0.16,67.63],["PER",8.0,0.38,68.04],["ITA",5.0,0.44,68.98],["ESP",5.0,0.23,74.77],["COL",2.0,0.35,55.96],["MEX",0.0,0.14,51.8]],"hovertemplate":"Importaciones (millones USD)=%{x}<br>Pa\u00eds=%{y}<br>reporter_iso=%{customdata[0]}<br>ARG_part=%{customdata[1]}<br>UE_part=%{customdata[2]}<br>CHN_part=%{customdata[3]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[5.15,5.3,5.33,6.18,6.56,6.9,7.01,8.16,8.95,9.97,11.12,12.22,12.43,13.36,14.28,19.14,19.62,22.22,28.3,167.23],"xaxis":"x","y":["El Salvador","Honduras","Jordania","Rep\u00fablica Dominicana","Israel","Costa Rica","Belar\u00fas","Chile","Malasia","Polonia","Marruecos","Portugal","Reino Unido","T\u00fanez","Arabia Saudita","Per\u00fa","Italia","Espa\u00f1a","Colombia","M\u00e9xico"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8" ...

# %%
# Cluster #3 imports. Annual Mean 2016-2020
df = df_vf.loc[df_vf['cluster'].isin([2])]
sd = df.nlargest(20,'media_value')
fd = sd.sort_values(by='media_value', ascending = True)


fig = px.bar(fd, x="media_value", y="reporter", orientation='h',
             hover_data=['reporter_iso','media_value', 'ARG_part', 'UE_part','CHN_part'],
             height=600,
             title='Top 20 Importaciones de países Cluster #3. Promedio anual 2016-2020',
             labels={'media_value': 'Importaciones (millones USD)', 'reporter':'País'})

py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="763bc6d5-101a-4d54-8885-036cdea505f2" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("763bc6d5-101a-4d54-8885-036cdea505f2")) {                    Plotly.newPlot(                        "763bc6d5-101a-4d54-8885-036cdea505f2",                        [{"alignmentgroup":"True","customdata":[["MLT",1.0,0.1,54.1],["LUX",0.0,0.34,52.54],["CYP",9.0,0.04,58.99],["SVK",0.0,0.37,60.58],["SVN",0.0,0.48,75.07],["ARE",6.0,0.24,76.98],["HUN",0.0,0.09,57.46],["IRL",7.0,0.32,62.34],["BEL",1.0,0.48,57.76],["NLD",1.0,1.0,71.01],["VNM",21.0,1.52,66.88]],"hovertemplate":"Importaciones (millones USD)=%{x}<br>Pa\u00eds=%{y}<br>reporter_iso=%{customdata[0]}<br>ARG_part=%{customdata[1]}<br>UE_part=%{customdata[2]}<br>CHN_part=%{customdata[3]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[0.65,0.79,1.42,1.71,1.77,3.11,3.7,6.72,10.27,15.95,43.09],"xaxis":"x","y":["Malta","Luxemburgo","Chipre","Eslovaquia","Eslovenia","Emiratos \u00c1rabes Unidos","Hungr\u00eda","Irlanda","B\u00e9lgica","Pa\u00edses Bajos","Viet Nam"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222 ...

# %%
# Cluster #4 imports. Annual Mean 2016-2020
df = df_vf.loc[df_vf['cluster'].isin([3])]
sd = df.nlargest(19,'media_value')
fd = sd.sort_values(by='media_value', ascending = True)


fig = px.bar(fd, x="media_value", y="reporter", orientation='h',
             hover_data=['reporter_iso','media_value', 'ARG_part', 'UE_part','CHN_part'],
             height=600,
             title='Top 20 Importaciones de países Cluster #4. Promedio anual 2016-2020',
             labels={'media_value': 'Importaciones (millones USD)', 'reporter':'País'})

py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3ce19531-1b95-4e47-9339-df86e168c083" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ce19531-1b95-4e47-9339-df86e168c083")) {                    Plotly.newPlot(                        "3ce19531-1b95-4e47-9339-df86e168c083",                        [{"alignmentgroup":"True","customdata":[["EST",0.0,0.35,57.51],["LVA",1.0,0.13,58.44],["BGR",0.0,3.07,57.21],["FIN",0.0,1.79,59.58],["LTU",3.0,0.89,57.67],["UKR",0.0,4.12,54.85],["URY",17.0,0.15,79.59],["PRY",11.0,0.32,85.92],["SWE",0.0,1.45,61.96],["NZL",12.0,0.79,74.39],["AUS",18.0,1.33,63.5],["DNK",7.0,2.3,57.46],["CAN",0.0,1.16,54.66],["FRA",1.0,0.38,66.08],["BRA",13.0,3.17,73.78],["DEU",0.0,1.23,63.31],["THA",2.0,0.64,81.54],["ARG",0.0,0.21,93.8],["JPN",0.0,3.5,64.61]],"hovertemplate":"Importaciones (millones USD)=%{x}<br>Pa\u00eds=%{y}<br>reporter_iso=%{customdata[0]}<br>ARG_part=%{customdata[1]}<br>UE_part=%{customdata[2]}<br>CHN_part=%{customdata[3]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[0.67,1.45,1.58,1.83,1.91,1.95,2.15,2.18,2.47,2.49,5.18,5.58,6.8,9.95,13.65,18.36,22.51,46.09,56.79],"xaxis":"x","y":["Estonia","Letonia","Bulgaria","Finlandia","Lituania","Ucrania","Uruguay","Paraguay","Suecia","Nueva Zelandia","Australia","Dinamarca","Canad\u00e1","Francia","Brasil","Alemania","Tailandia","Argentina","Jap\u00f3n"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555 ...

# %%
# Cluster #5 imports. Annual Mean 2016-2020
df = df_vf.loc[df_vf['cluster'].isin([4])]
sd = df.nlargest(20,'media_value')
fd = sd.sort_values(by='media_value', ascending = True)


fig = px.bar(fd, x="media_value", y="reporter", orientation='h',
             hover_data=['reporter_iso','media_value', 'ARG_part', 'UE_part','CHN_part'],
             height=600,
             title='Top 20 Importaciones de países Cluster #5. Promedio anual 2016-2020',
             labels={'media_value': 'Importaciones (millones USD)', 'reporter':'País'})

py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0822a72f-3857-40c5-b9a1-2cf95e3d8ae3" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0822a72f-3857-40c5-b9a1-2cf95e3d8ae3")) {                    Plotly.newPlot(                        "0822a72f-3857-40c5-b9a1-2cf95e3d8ae3",                        [{"alignmentgroup":"True","customdata":[["KAZ",2.0,0.31,92.66],["MDG",1.0,0.31,89.69],["LKA",0.0,1.01,78.8],["SEN",18.0,0.07,68.41],["KHM",5.0,1.08,88.15],["MMR",0.0,1.45,81.21],["SDN",0.0,0.54,94.63],["ETH",0.0,0.04,67.18],["UZB",2.0,0.12,87.68],["NPL",0.0,0.43,93.74],["PAK",4.0,3.61,86.1],["GTM",0.0,0.25,62.29],["NGA",1.0,0.51,74.21],["IND",0.0,1.89,94.22],["PHL",6.0,1.46,62.63],["TUR",5.0,0.21,87.07],["DZA",24.0,0.01,69.66],["IDN",11.0,0.5,63.68],["EGY",9.0,0.14,82.31],["CHN",3.0,0.0,82.65]],"hovertemplate":"Importaciones (millones USD)=%{x}<br>Pa\u00eds=%{y}<br>reporter_iso=%{customdata[0]}<br>ARG_part=%{customdata[1]}<br>UE_part=%{customdata[2]}<br>CHN_part=%{customdata[3]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[1.92,1.94,2.03,2.48,2.54,2.71,3.75,3.85,4.33,5.74,5.75,8.03,11.99,13.38,13.69,21.9,26.47,32.73,45.66,478.35],"xaxis":"x","y":["Kazajst\u00e1n","Madagascar","Sri Lanka","Senegal","Camboya","Myanmar","Sud\u00e1n","Etiop\u00eda","Uzbekist\u00e1n","Nepal","Pakist\u00e1n","Guatemala","Nigeria","India","Filipinas","Turqu\u00eda","Argelia","Indonesia","Egipto","China"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333333333333 ...

# %%
df_world = df1.loc[df1['partner_iso'].isin(['WLD'])]
df_world = df_world.sort_values(by=['reporter'], ascending = [True]).groupby(['reporter','reporter_iso', 'year']).agg(total =  ('trade_value_usd', sum))
df_world['%-Change']=df_world.groupby(['reporter', 'reporter_iso'])['total'].apply(lambda x: x/x.shift(1)-1).fillna(0)*100
df_mean_var = df_world.sort_values(by=['reporter'], ascending = [True]).groupby(['reporter','reporter_iso']).agg(mean_var =  ('%-Change', 'mean'))
df_mean_var['mean_var'] = df_mean_var['mean_var'].round(2)

# %%
#Merge de bases de variables + importaciones
df_pc_var = pd.merge(df_vf, df_mean_var, on = 'reporter_iso', how = 'inner')
df_pc_var.shape
# Out:
# (133, 26)

# %%
# value column equals to 0.0
indexNames = df_pc_var[(df_pc_var['reporter'] == 'Panamá')].index
# Delete these row indexes from dataFrame
df_pc_var.drop(indexNames , inplace=True)

# %%
# PCA and Clusters Scatter Plot

fig = px.scatter(df_pc_var, x=df_pc_var['PC1'], y=df_pc_var['mean_var'], color=df_pc_var['cluster'],hover_data = ['reporter_iso', 'reporter'], color_discrete_sequence=px.colors.qualitative.Antique,
                 labels={'PC1': 'Componente Principal #1', 'mean_var':'Variación % - Promedio anual'})

py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="71387759-c067-4983-a0b4-e56296b33842" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71387759-c067-4983-a0b4-e56296b33842")) {                    Plotly.newPlot(                        "71387759-c067-4983-a0b4-e56296b33842",                        [{"customdata":[["AFG","Afganist\u00e1n"],["AGO","Angola"],["ALB","Albania"],["ARE","Emiratos \u00c1rabes Unidos"],["ARG","Argentina"],["ARM","Armenia"],["ATG","Antigua y Barbuda"],["AUS","Australia"],["AUT","Austria"],["AZE","Azerbaiy\u00e1n"],["BEL","B\u00e9lgica"],["BEN","Benin"],["BFA","Burkina Faso"],["BGR","Bulgaria"],["BHS","Bahamas"],["BIH","Bosnia y Herzegovina"],["BLR","Belar\u00fas"],["BLZ","Belice"],["BRA","Brasil"],["BRB","Barbados"],["BWA","Botswana"],["CAN","Canad\u00e1"],["CHE","Suiza"],["CHL","Chile"],["CHN","China"],["CIV","C\u00f4te d'Ivoire"],["CMR","Camer\u00fan"],["COG","Congo"],["COL","Colombia"],["CPV","Cabo Verde"],["CRI","Costa Rica"],["CYP","Chipre"],["DEU","Alemania"],["DNK","Dinamarca"],["DOM","Rep\u00fablica Dominicana"],["DZA","Argelia"],["ECU","Ecuador"],["EGY","Egipto"],["ESP","Espa\u00f1a"],["EST","Estonia"],["ETH","Etiop\u00eda"],["FIN","Finlandia"],["FJI","Fiji"],["FRA","Francia"],["GBR","Reino Unido"],["GEO","Georgia"],["GHA","Ghana"],["GIN","Guinea"],["GMB","Gambia"],["GRC","Grecia"],["GRD","Granada"],["GRL","Dinamarca"],["GTM","Guatemala"],["GUY","Guyana"],["HND","Honduras"],["HRV","Croacia"],["HUN","Hungr\u00eda"],["IDN","Indonesia"],["IND","India"],["IRL","Irlanda"],["ISL","Islandia"],["ISR","Israel"],["ITA","Italia"],["JAM","Jamaica"],["JOR","Jordania"],["JPN","Jap\u00f3n"],["KAZ","Kazajst\u00e1n"],["KEN","Kenya"],["KGZ","Kirguist\u00e1n"],["KHM","Camboya"],["KWT","Kuwait"],["LBN","L\u00edbano"],["LCA","Santa Luc\u00eda"],["LKA","Sri Lanka"],["LSO","Lesotho"],["LTU","Lituania"],["LUX","Luxemburgo"],["LVA","Letonia"],["MAR","Marruecos"],["MDG","Madagascar"],["MEX","M\u00e9xico"],["MLI","Mal\u00ed"],["MLT","Malta"],["MMR","Myanmar"],["MNE","Montenegro"],["MNG","Mongolia"],["MOZ","Mozambique"],["MUS","Mauricio"],["MWI","Malawi"],["MYS","Malasia"],["NAM","Namibia"],["NER","N\u00edger"],["NGA","Nigeria"],["NIC","Nicaragua"],["NLD","Pa\u00edses Bajos"],["NOR","Noruega"],["NPL","Nepal"],["NZL","Nueva Zelandia"],["OMN","Om\u00e1n"],["PAK","Pakist\u00e1n"],["PER","Per\u00fa"],["PHL","Filipinas"],["POL","Polonia"],["PRT","Portugal"],["PRY","Paraguay"],["PYF","Francia"],["ROU","Rumania"],["RWA","Rwanda"],["SAU","Arabia Saudita"],["SDN","Sud\u00e1n"],["SEN","Senegal"],["SLE","Sierra Leona"],["SLV","El Salvador"],["SRB","Serbia"],["SUR","Suriname"],["SVK","Eslovaquia"],["SVN","Eslovenia"],["SWE","Suecia"],["TGO","Togo"],["THA","Tailandia"],["TJK","Tayikist\u00e1n"],["TUN","T\u00fanez"],["TUR","Turqu\u00eda"],["UGA","Uganda"],["UKR","Ucrania"],["URY","Uruguay"],["UZB","Uzbekist\u00e1n"],["VNM","Viet Nam"],["YEM","Yemen"],["ZAF","Sud\u00e1frica"],["ZMB","Zambia"],["ZWE","Zimbabwe"]],"hovertemplate":"Componente Principal #1=%{x}<br>Variaci\u00f3n % - Promedio anual=%{y}<br>reporter_iso=%{customdata[0]}<br>reporter=%{customdata[1]}<br>cluster=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0,0,1,2,3,1,0,3,1,0,2,4,4,3,0,1,1,0,3,0,0,3,1,1,4,4,4,1,1,0,1,2,3,3,1,4,0,4,1,3,4,3,0,3,1,1,4,4,0,1,0,3,4,4,1,1,2,4,4,2,1,1,1,1,1,3,4,4,4,4,1,0,0,4,0,3,2,3,1,4,1,4,2,4,0,4,0,1,4,1,0,4,4,0,2,1,4,3,1,4,1,4,1,1,3,3,1,4,1,4,4,4,1,1,0,2,2,3,4,3,4,1,4,4,3,3,4,2,0,1,4,0],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-4.66,-1.75,0.34,2.28,-0.06,0.03,-1.26,2.46,2.06,-1.32,2.77,-1.99,-1.84,2.95,-2.06,0.32,0.85,-0.91,0.4,-1.1,-1.87,2.27,1.79,0.98,-0.12,-0.77,-1.26,0.33,-0.2,-2.12,0.73,1.57,1.99,3.28,-0.25,-1 ...
