# %% [markdown]
# #***ADECUACIÓN DE BASE DE DATOS***
#
# ---
#
#
#
# ---

# %%
# !pip install chart_studio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting chart_studio
#   Downloading chart_studio-1.1.0-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 1.2 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from chart_studio) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from chart_studio) (2.23.0)
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from chart_studio) (5.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly->chart_studio) (8.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (1.24.3)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py) ... done
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11447 sha256=1b50726c106771b5bc0c04db7f5af0fefbcbe4e2de147bc8052e6b24de874a6d
#   Stored in directory: /root/.cache/pip/wheels/f9/8d/8d/f6af3f7f9eea3553bc2fe6d53e4b287dad18b06a861ac56ddf
# Successfully built retrying
# Installing collected packages: retrying, chart-studio
# Successfully installed chart-studio-1.1.0 retrying-1.3.3

# %%
import numpy as np
import pandas as pd 

from sklearn import preprocessing # Data Scaling
from sklearn import decomposition #PCA
from sklearn.cluster import KMeans

import chart_studio
from chart_studio import plotly as py
import plotly.graph_objs as go
import chart_studio.tools as tls
import plotly.express as px

# %%
#Login Chart-Studio Plotly
username = 'gabrielfernande.z'
api_key = 'KbGOwwZFLEclyQceHUm4'

chart_studio.tools.set_credentials_file(username=username, api_key=api_key)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/Agencia/molineria/Molinera_animal.csv')

# %%
df1 = df[['year', 'reporter_code','reporter', 'reporter_iso', 'partner_code', 'partner',
       'partner_iso', 'commodity_code','commodity', 'trade_value_usd']]

# %%
df1['commodity_code'].astype('int', errors='ignore')
ncm = [71320.0] 
    
# selecting rows based on condition 
df1.loc[df1['commodity_code'].isin(ncm)]

# %%
df1['trade_value_usd'] = df1['trade_value_usd'] / 1000000
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# Python: sorting and aggregations
df_agg = df1.sort_values(by=['reporter_iso','year'], ascending = [True, True]).groupby(['reporter_iso','year',]).agg(
    first_value =  ('trade_value_usd', 'first'),
    last_value =  ('trade_value_usd', 'last'),
    total =  ('trade_value_usd', sum),
    promedio = ('trade_value_usd', 'mean'))

# %%
df_agg['var_impo'] = ((df_agg['last_value'] / df_agg['first_value'])-1) * 100

# %%
#Calculo mediana
mediana = df_agg['promedio'].median()
mediana
#Nueva columna (feature, variable), si promedio de importaciones (totales) es mayor a la Mediana
df_agg['mayor_mediana'] = np.where(df_agg['promedio'] < mediana, "NO", "SI")

# %%
#Nueva columna (feature, variable), si promedio de importaciones (totales) es mayor a la Mediana
df_agg['mayor_mediana'] = np.where(df_agg['promedio'] < mediana, "NO", "SI")

# %%
UE = ["USA","DEU","AUT","BEL","BGR","CYP","HRV","DNK","SVK","SVN","ESP","EST",
      "FIN","FRA","GRC","HUN","IRL","ITA","LVA","LTU","LUX","MLT","MCO","NLD",
      "POL","PRT","GBR","CZE","ROU","SMR","SWE"]

# %%
# Genero columna de partners con partner_iso
result = []
for value in df1['partner_iso']:
  if value == "ARG":
    result.append("ARG")
  elif value == "CHN":
    result.append("CHN")
  elif value in UE:
    result.append("UE")
  else:
    result.append("Resto")
   
df1["procedencia"] = result
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
# i) Creo df de totales y ii) desagregago por partners (totales y media)
df_salud_proc = df1.sort_values(by=['reporter_iso'], ascending = [True]).groupby(['reporter_iso']).agg(total =  ('trade_value_usd', sum),
                                                                                                    media_value = ('trade_value_usd', 'mean'),
                                                                                                    first = ('trade_value_usd', 'first'),
                                                                                                    last =('trade_value_usd', 'last'),
                                                                                                    last_year = ('year', 'last'))

df_salud_proc2 = df1.sort_values(by=['reporter_iso'], ascending = [True]).groupby(['reporter_iso','procedencia']).agg(total =  ('trade_value_usd', sum),
                                                                                                                   media =('trade_value_usd', 'mean'),
                                                                                                                   first = ('trade_value_usd', 'first'),
                                                                                                                   last =('trade_value_usd', 'last'))

df_salud_proc2 = df_salud_proc2.unstack()

df_salud_proc2.columns = ['ARG_sum','UE_sum','CHN_sum','Resto_sum',
                          'ARG_media','UE_media','CHN_media','Resto_media',
                          'ARG_first','UE_first','CHN_first','Resto_first',
                          'ARG_last','UE_last','CHN_last','Resto_last']
# Merge i) y ii)
df_salud_proc3 = pd.merge(df_salud_proc, df_salud_proc2, left_index=True, right_index=True)

#Calculo participacion de cada partner por iso_pais
df_salud_proc3['ARG_part'] = (df_salud_proc3['ARG_sum'] / df_salud_proc3['total'])*100  
df_salud_proc3['UE_part'] = (df_salud_proc3['UE_sum'] / df_salud_proc3['total'])*100  
df_salud_proc3['CHN_part'] = (df_salud_proc3['CHN_sum'] / df_salud_proc3['total'])*100  
df_salud_proc3['Resto_part'] = (df_salud_proc3['Resto_sum'] / df_salud_proc3['total'])*100  

#Calculo variaciones de importaciones para el iso_pais, mediana, y si el pais está encima o debajo de la mediana
df_salud_proc3['var_impo'] = ((df_salud_proc3['last'] / df_salud_proc['first'])-1)*100

mediana = df_salud_proc3['media_value'].median()
df_salud_proc3['mayor_median'] = np.where(
    df_salud_proc['media_value'] < mediana, "NO", "SI")

# %%
df_salud_proc3 = df_salud_proc3.reset_index()

# %%
df_salud_proc3['ARG_part'] = df_salud_proc3['ARG_part'].fillna(0).astype(int)

impo_global = df_salud_proc3[['reporter_iso','total', 'media_value', 'ARG_part', 'UE_part', 'CHN_part', 'Resto_part', 'last_year']]
impo_global = impo_global.round(2)
#impo_global.columns = ['Total', 'Mean', 'Part. Arg', 'Part. UE', 'Part. China', 'Part. Rest', 'Last Year' ]

# %%
impo_global = impo_global.reset_index()

# %%
filename = '/content/drive/My Drive/Agencia/equipamiento_medico/cod_paises.csv' 
f = open(filename, "r")
cod_paises = pd.read_csv(filename, sep=',', encoding= 'unicode_escape')

# %%
cod_paises.columns = ['reporter_iso','continente','reporter','zona']

# %%
#Merge entre base con el listado de codigos de paises
df_salud_proced = pd.merge(df_salud_proc3, cod_paises, on = 'reporter_iso')

# %%
#Fillna para conservar la variable ARG_part y no excluir tantos paises en el PCA
df_salud_proced[['ARG_sum','ARG_media','ARG_first','ARG_part','ARG_last']] = df_salud_proced[['ARG_sum','ARG_media','ARG_first','ARG_part','ARG_last']].fillna(0).astype(int)

# %%
df_salud_proced.shape
# Out:
# (169, 31)

# %%
df_salud_proced2 = df_salud_proced

# %%
#Guardo como CSV
df_salud_proced2.to_csv("/content/drive/MyDrive/Agencia/molineria/df_salud_proced2.csv", index=False)

# %% [markdown]
# #**CLUSTERIZACIÓN**
#
# ---
#
#
#
# ---

# %%
#Import economic, demografic and health spending (public & private) (World Bank Data Base)
filename = '/content/drive/My Drive/Agencia/maquinaria/dbs/variables.xlsx' 
filename1 = '/content/drive/My Drive/Agencia/molineria/indicadores/indicadores.csv' 
f = open(filename, "r")
data_gral = pd.read_excel(filename)#, sep=',', encoding= 'unicode_escape')
index_molineria = pd.read_csv(filename1)

# %%
#Impute NaN with zeros
#data_gral['C2'] = data_gral['C2'].replace(0, np.nan)
#data_gral['S7'] = data_gral['S7'].fillna(0).astype(int)

# %%
#Rename columns
#data_gral.columns = ['reporter', 'reporter_iso', 'D1', 'D3', 'D7', 'E3', 'E5', 'C2',
#       'C4', 'S3', 'S5', 'S7', 'G1', 'G7', 'G8']

# %%
data_gral.columns = ['reporter_iso', 'agro_land', 'ied', 'idl', 'x_pbi', 'm_pbi', 'agro_pbi',
       'pbi_growth', 'tasa_min']

# %%
data_gral = data_gral[['reporter_iso', 'idl', 'x_pbi', 'm_pbi',
       'pbi_growth', 'tasa_min']]

# %%
data_gral = pd.merge(data_gral, index_molineria, on = 'reporter_iso', how = 'inner')

# %%
df_salud_proced2.columns
# Out:
# Index(['reporter_iso', 'total', 'media_value', 'first', 'last', 'last_year',
#        'ARG_sum', 'UE_sum', 'CHN_sum', 'Resto_sum', 'ARG_media', 'UE_media',
#        'CHN_media', 'Resto_media', 'ARG_first', 'UE_first', 'CHN_first',
#        'Resto_first', 'ARG_last', 'UE_last', 'CHN_last', 'Resto_last',
#        'ARG_part', 'UE_part', 'CHN_part', 'Resto_part', 'var_impo',
#        'mayor_median', 'continente', 'reporter', 'zona'],
#       dtype='object')

# %%
#Select columns from imports dataframe
df_salud_sub = df_salud_proced2[['media_value', 'ARG_part', 'UE_part','CHN_part','reporter_iso']]

#Merge
df_cluster_vf = pd.merge(data_gral, df_salud_sub, on = 'reporter_iso', how = 'inner')

# %%
df_cluster_vf = df_cluster_vf.drop(['reporter', 'continente', 'zona'], 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
#Drop NaN (sine qua non condition to apply PCA)
data_pc = df_cluster_vf.dropna()
data_pc = data_pc.set_index('reporter_iso')

# %%
data_pc.head(1)
# Out:
#                idl  x_pbi  m_pbi  pbi_growth  tasa_min    D1      D2     D3  \
# reporter_iso
# AFG           1.95    0.0    0.0     1.53141       6.5  41.6  2141.8  337.0
#
#                 D4     D5     D6  media_value  ARG_part   UE_part   CHN_part
# reporter_iso
# AFG           33.0  76.25  92.42     3.364448         0  0.036727  99.843614

# %%
#Subset PCA
data_pc_slice = data_pc.iloc[:,0:15]
columns_slice = data_pc_slice.columns
data_pc_slice = data_pc_slice.astype(float)
data_pc_slice.shape
# Out:
# (132, 15)

# %%
#Preprossecing data
#data_x = preprocessing.scale(data_pc_slice)
#data_x = pd.DataFrame(data_x, columns = columns_slice)

data_x = preprocessing.StandardScaler().fit_transform(data_pc_slice)
data_x = pd.DataFrame(data_x, columns = columns_slice)

# %%
#PRINCIPAL COMPONENTS ANALYSIS
pca = decomposition.PCA(n_components=5)
pca.fit(data_x)
comp = pca.transform(data_x)
comp_df = pd.DataFrame(comp, columns=['PC1', 'PC2', 'PC3','PC4', 'PC5'])

# %%
#Dataframa WB variables, Imports and PCs
df_slice_comp = pd.merge(data_x, comp_df, left_index=True, right_index=True)

# %%
#KMEANS CLUSTERING
kmean = KMeans(n_clusters = 5, max_iter = 10000, n_init = 50)
kmean.fit(comp)
# Out:
# KMeans(max_iter=10000, n_clusters=5, n_init=50)

# %%
#Cluster identification
#kMEANS labels to dataframe
clusters = kmean.labels_
clusters = pd.DataFrame(clusters, columns = ['cluster'])

#iso codes 
data_pc = data_pc_slice.reset_index() 

#Unir iso_pais, con df_slice_comp y cluster
df_vf = pd.merge(data_pc, comp_df, left_index=True, right_index=True)
df_vf = pd.merge(df_vf, clusters, left_index=True, right_index=True)

#Select columns
features = df_vf.columns[1:-6]

# %%
df_vf.head()
# Out:
#   reporter_iso   idl      x_pbi      m_pbi  pbi_growth  tasa_min     D1  \
# 0          AFG  1.95   0.000000   0.000000    1.531410    6.5000   41.6
# 1          AGO  2.05  35.019373  25.620855   -2.151105    9.8425   42.1
# 2          ALB  2.66  29.307644  44.106203    1.858918    3.7240   38.4
# 3          ARE  3.96  97.622402  72.171329    0.764932    4.9940  100.0
# 4          ARG  2.89  14.514365  14.387358   -2.760085   13.3940 -165.8
#
#        D2     D3     D4  ...  media_value  ARG_part    UE_part   CHN_part  \
# 0  2141.8  337.0   33.0  ...     3.364448       0.0   0.036727  99.843614
# 1  2109.2    7.0   45.0  ...     1.176252       0.0   0.465070  67.333960
# 2  2488.4   21.5  161.0  ...     2.425088       6.0   0.039432  59.561855
# 3  2665.8    5.0   23.0  ...     4.540021      11.0   0.343448  71.226740
# 4  2413.0    5.0  346.0  ...     2.826464       0.0  10.730331  74.607612
#
#         PC1       PC2       PC3       PC4       PC5  cluster
# 0 -4.745250  1.179450  0.324807 -1.571749 -1.087742        0
# 1 -1.832344  0.738184  0.409820 -0.144415 -0.549710        0
# 2  0.564522  0.885768  0.703132  0.110995 -0.684861        3
# 3  2.264828  2.181569  0.606452  1.812780 -0.410050        4
# 4  0.536335 -3.039062 -1.323452 -1.894676 -2.334419        2
#
# [5 rows x 22 columns]

# %%
features
# Out:
# Index(['idl', 'x_pbi', 'm_pbi', 'pbi_growth', 'tasa_min', 'D1', 'D2', 'D3',
#        'D4', 'D5', 'D6', 'media_value', 'ARG_part', 'UE_part', 'CHN_part'],
#       dtype='object')

# %%
#Loadings matrix: correlation matrix
loadings_matrix = pd.DataFrame(pca.components_.T, columns=['PC1', 'PC2','PC3','PC4', 'PC5'], index=features)
loadings_matrix = loadings_matrix.reset_index()
loadings_matrix.columns = ['Referencia', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5'] 
#loadings_matrix = loadings_matrix.astype(str)

#Variables description
variables = {
    'Referencia': ['idl', 'x_pbi', 'm_pbi', 'pbi_growth','tasa_min', 'D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'media_value', 'ARG_part', 'UE_part', 'CHN_part'],
    'Descripción': ['Índice de Desempeño Logístico','Exportaciones de bienes y servicios (% del PIB)', 'Importaciones de bienes y servicios (% del PIB)', 'Crecimiento del PIB (% anual)', 
                    'Tasa mínima arancelaria (%)', 'Coeficiente de dependencia de las importaciones de cereales (%)', 'Requerimiento promedio de energía alimentaria (kcal/cap/día)',
                    'Valor de las importaciones de alimentos respecto de las exportaciones totales de mercancías (%)','Valor medio de la producción de alimentos (I$ constante por persona)',
                    'Variabilidad del suministro de alimentos per cápita (kcal/persona/día)', 'Índice produccion bruto p.c. alimentos y ganado',
                    'Importaciones promedio 2017-2021','Participación argentina en importaciones', 'Participación UE en importaciones', 'Participación china en importaciones'
                    ]
}

variables = pd.DataFrame(variables)

#Merge loadings and variables descriptions
loadings_matrix_detalle = pd.merge(loadings_matrix, variables, on = 'Referencia')

# %% [markdown]
# #***PLOTS***
#
# ---
#
#
#
# ---

# %%
df_vf = pd.merge(df_vf, cod_paises, on = 'reporter_iso', how = 'inner')

# %%
df_vf.iloc[:, 1:20] = df_vf.iloc[:, 1:20].round(2) # Remember that Python does not slice inclusive of the ending index.

# %%
df_vf.reporter = df_vf.reporter.replace('Reino Unido de Gran Bretaña e Irlanda del Norte', 'Reino Unido')

# %%
# PCA and Clusters Scatter Plot


fig = px.scatter(df_vf, x=df_vf['PC1'], y=df_vf['PC2'], color=df_vf['cluster'],hover_data = ['reporter_iso', 'reporter','media_value', 'ARG_part', 'UE_part','CHN_part'], color_discrete_sequence=["green", "blue", "yellow", "magenta", "black"],
                 labels={'PC1': 'Componente Principal #1', 'PC2':'Componente Principal #2'})

#py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ac5f8bb8-eda3-4077-bc95-8131c5b1dfa8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac5f8bb8-eda3-4077-bc95-8131c5b1dfa8")) {                    Plotly.newPlot(                        "ac5f8bb8-eda3-4077-bc95-8131c5b1dfa8",                        [{"customdata":[["AFG","Afganist\u00e1n",3.36,0.0,0.04,99.84],["AGO","Angola",1.18,0.0,0.47,67.33],["ALB","Albania",2.43,6.0,0.04,59.56],["ARE","Emiratos \u00c1rabes Unidos",4.54,11.0,0.34,71.23],["ARG","Argentina",2.83,0.0,10.73,74.61],["ARM","Armenia",1.24,0.0,0.27,73.17],["ATG","Antigua y Barbuda",0.41,0.0,0.04,74.42],["AUS","Australia",19.44,20.0,1.2,60.46],["AUT","Austria",13.53,0.0,0.28,62.69],["AZE","Azerbaiy\u00e1n",1.99,12.0,0.11,81.04],["BEL","B\u00e9lgica",31.8,2.0,0.54,52.13],["BEN","Benin",0.28,0.0,0.8,53.2],["BFA","Burkina Faso",0.16,0.0,0.59,83.17],["BGR","Bulgaria",3.85,0.0,5.01,51.78],["BHS","Bahamas",1.07,0.0,0.01,50.28],["BIH","Bosnia y Herzegovina",3.49,0.0,0.03,79.95],["BLR","Belar\u00fas",8.57,14.0,1.02,75.78],["BLZ","Belice",1.37,0.0,0.0,87.56],["BRA","Brasil",11.26,1.0,12.27,56.04],["BRB","Barbados",0.64,0.0,0.07,69.97],["BWA","Botswana",3.71,0.0,0.0,99.98],["CAN","Canad\u00e1",25.68,0.0,1.29,52.5],["CHE","Suiza",7.97,0.0,1.25,61.04],["CHL","Chile",14.44,14.0,1.0,74.53],["CHN","China",15.27,0.0,0.04,73.91],["CIV","C\u00f4te d'Ivoire",2.5,23.0,0.18,54.67],["CMR","Camer\u00fan",1.7,29.0,0.14,51.89],["COG","Congo",0.21,2.0,0.13,57.48],["COL","Colombia",27.87,0.0,1.09,62.37],["CPV","Cabo Verde",0.31,0.0,0.01,51.06],["CRI","Costa Rica",4.25,0.0,0.62,72.25],["CYP","Chipre",3.79,15.0,0.06,51.87],["DEU","Alemania",46.47,1.0,2.72,60.96],["DNK","Dinamarca",19.45,9.0,2.46,57.0],["DOM","Rep\u00fablica Dominicana",5.22,0.0,0.76,57.28],["ECU","Ecuador",26.22,7.0,0.29,76.58],["EGY","Egipto",12.68,32.0,1.47,54.57],["ESP","Espa\u00f1a",26.23,17.0,0.74,58.82],["EST","Estonia",1.67,0.0,0.35,56.31],["ETH","Etiop\u00eda",0.48,0.0,0.49,59.41],["FIN","Finlandia",6.25,0.0,2.43,56.91],["FJI","Fiji",1.61,0.0,0.04,99.23],["FRA","Francia",31.31,1.0,0.5,67.64],["GBR","Reino Unido",39.29,9.0,2.1,56.26],["GEO","Georgia",1.52,0.0,0.08,80.24],["GHA","Ghana",1.92,20.0,1.08,60.46],["GIN","Guinea",0.18,0.0,0.59,52.83],["GMB","Gambia",0.03,0.0,0.41,72.63],["GRC","Grecia",8.15,18.0,0.39,52.8],["GRD","Granada",0.18,0.0,0.0,78.03],["GRL","Dinamarca",0.1,0.0,0.48,51.2],["GTM","Guatemala",9.41,0.0,0.6,60.77],["GUY","Guyana",0.86,0.0,0.01,65.11],["HND","Honduras",7.69,0.0,0.19,68.29],["HRV","Croacia",7.29,0.0,0.05,54.24],["HUN","Hungr\u00eda",9.52,0.0,0.05,54.02],["IDN","Indonesia",55.63,22.0,0.97,71.14],["IND","India",9.51,0.0,6.29,80.18],["IRL","Irlanda",14.67,12.0,0.62,56.17],["ISL","Islandia",2.82,0.0,0.23,75.41],["ISR","Israel",5.27,2.0,1.62,64.45],["ITA","Italia",36.2,15.0,0.56,57.67],["JAM","Jamaica",5.22,0.0,0.07,55.07],["JOR","Jordania",5.53,37.0,1.12,53.58],["JPN","Jap\u00f3n",40.59,0.0,12.12,69.21],["KAZ","Kazajst\u00e1n",4.0,4.0,0.55,87.8],["KEN","Kenya",1.75,0.0,0.81,88.73],["KGZ","Kirguist\u00e1n",0.53,1.0,0.68,84.69],["KHM","Camboya",6.75,2.0,1.52,88.32],["KWT","Kuwait",1.58,0.0,0.28,81.66],["LBN","L\u00edbano",2.66,29.0,0.56,54.6],["LCA","Santa Luc\u00eda",0.59,0.0,0.01,88.42],["LKA","Sri Lanka",4.26,0.0,1.4,67.02],["LSO","Lesotho",0.78,0.0,0.01,94.76],["LTU","Lituania",4.99,5.0,1.25,51.39],["LUX","Luxemburgo",1.92,0.0,0.47,52.53],["LVA","Letonia",3.7,2.0,0.18,51.03],["MAR","Marruecos",10.33,16.0,0.58,50.68],["MDG","Madagascar",1.69,2.0,0.19,69.68],["MEX","M\u00e9xico",98.62,0.0,0.75,52.51],["MLI","Mal\u00ed",0.68,1.0,0.73,56.36],["MLT","Malta",1.48,0.0,0.15,52.18],["MMR","Myanmar",4.64,0.0,1.88,77.36],["MNE","Montenegro",0.7,0.0,0.07,85.95],["MNG","Mongolia",0.4,0.0,19.02,75.51],["MOZ","Mozamb ...

# %%
df_comp = df_vf[['PC1', 'PC2', 'PC3', 'PC4', 'PC5','reporter', 'cluster']]

# %%
df_vf.reporter = df_vf.reporter.replace('Hong Kong (región administrativa especial de China)', 'Hong Kong')
df_vf.reporter = df_vf.reporter.replace('Macao (región administrativa especial de China)', 'Macao')

# %%
# Top 20 reporters. Anual Mean 2017-2021
df = df_vf
sd = df.nlargest(20,'media_value')
fd = sd.sort_values(by='media_value', ascending = True)

fig = px.bar(fd, x="media_value", y="reporter", orientation='h',
             hover_data=['reporter_iso','media_value', 'ARG_part', 'UE_part','CHN_part'],
             height=600,
             title='Principales importadores a nivel global: top 20 importadores. Promedio anual 2016-2020',
             labels={'media_value': 'Importaciones (millones USD)', 'reporter':'País'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="664d24fd-dd9e-46b7-b7f5-4eb0233bb94f" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("664d24fd-dd9e-46b7-b7f5-4eb0233bb94f")) {                    Plotly.newPlot(                        "664d24fd-dd9e-46b7-b7f5-4eb0233bb94f",                        [{"alignmentgroup":"True","customdata":[["AUS",20.0,1.2,60.46],["DNK",9.0,2.46,57.0],["PER",2.0,0.84,84.44],["CAN",0.0,1.29,52.5],["ECU",7.0,0.29,76.58],["ESP",17.0,0.74,58.82],["THA",6.0,1.71,81.14],["COL",0.0,1.09,62.37],["PHL",9.0,1.12,55.08],["FRA",1.0,0.5,67.64],["NLD",3.0,2.77,67.5],["BEL",2.0,0.54,52.13],["POL",14.0,0.64,61.69],["ITA",15.0,0.56,57.67],["GBR",9.0,2.1,56.26],["JPN",0.0,12.12,69.21],["DEU",1.0,2.72,60.96],["IDN",22.0,0.97,71.14],["VNM",30.0,3.15,60.93],["MEX",0.0,0.75,52.51]],"hovertemplate":"Importaciones (millones USD)=%{x}<br>Pa\u00eds=%{y}<br>reporter_iso=%{customdata[0]}<br>ARG_part=%{customdata[1]}<br>UE_part=%{customdata[2]}<br>CHN_part=%{customdata[3]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[19.44,19.45,20.65,25.68,26.22,26.23,27.86,27.87,30.23,31.31,31.45,31.8,33.33,36.2,39.29,40.59,46.47,55.63,59.51,98.62],"xaxis":"x","y":["Australia","Dinamarca","Per\u00fa","Canad\u00e1","Ecuador","Espa\u00f1a","Tailandia","Colombia","Filipinas","Francia","Pa\u00edses Bajos","B\u00e9lgica","Polonia","Italia","Reino Unido","Jap\u00f3n","Alemania","Indonesia","Viet Nam","M\u00e9xico"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a ...

# %%
#LATAM imports. Anual Mean 2016-2020 

latam = ['ARG','ABW','BHS','BRB','BLZ','BMU','BOL','BRA','CHL','COL','CRI','CUB','ECU','SLV','GTM',
         'GUF','GUY','HTI','HND','FLK','JAM','MEX','NIC','PAN','PRY','PER','PRI','DOM','SUR','TTO',
         'URY','VEN']

df = df_salud_proced.loc[df_salud_proced['reporter_iso'].isin(latam)]
sd = df.nlargest(20,'media_value')
fd = sd.sort_values(by='media_value', ascending = True)

fig = px.bar(fd, x="media_value", y="reporter", orientation='h',
             hover_data=['reporter_iso','media_value', 'ARG_part', 'UE_part','CHN_part'],
             height=600,
             title='Importaciones de Latinoamérica. Promedio anual 2016-2020',
             labels={'media_value': 'Importaciones (millones USD)', 'reporter':'País'})


#py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7a1dcfe7-49bc-48dc-a09d-5f780c37593c" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a1dcfe7-49bc-48dc-a09d-5f780c37593c")) {                    Plotly.newPlot(                        "7a1dcfe7-49bc-48dc-a09d-5f780c37593c",                        [{"alignmentgroup":"True","customdata":[["BLZ",0,0.00041989642427162245,87.56248095189292],["ABW",0,null,59.95619056143499],["BOL",18,2.3033665676229185,72.7748659854708],["ARG",0,10.730331427947352,74.60761186984007],["URY",17,0.2396592347665619,78.45195601881275],["CRI",0,0.6194441594133385,72.24999199029615],["PAN",0,0.4426507989119835,68.33312499280164],["DOM",0,0.7622038167330771,57.283352219260394],["JAM",0,0.06716324698481203,55.07165529259924],["NIC",0,0.009574307653408835,75.07426397865218],["PRY",9,0.3719155485227804,87.56152456972714],["SLV",0,0.23901648913325588,64.34756493689412],["HND",0,0.18747564990217216,68.2874310743824],["GTM",0,0.6014454570321025,60.77199539002252],["BRA",1,12.268870525877434,56.03640488552655],["CHL",14,0.9980903154862149,74.52513594992004],["PER",2,0.840625317153465,84.43534566165535],["ECU",7,0.2934633717636767,76.57843483817709],["COL",0,1.0904258883267162,62.37188235446125],["MEX",0,0.7549882429206728,52.51414541119882]],"hovertemplate":"Importaciones (millones USD)=%{x}<br>Pa\u00eds=%{y}<br>reporter_iso=%{customdata[0]}<br>ARG_part=%{customdata[1]}<br>UE_part=%{customdata[2]}<br>CHN_part=%{customdata[3]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[1.3737723684210525,1.7920440666666666,2.6272524484848483,2.826464090909091,2.942267695431472,4.250395335526316,5.20528356097561,5.217653338842975,5.221736824000001,5.295476463541667,5.5072814188034185,5.615907193133047,7.686917692307692,9.409241390977444,11.262511149797572,14.435582099526066,20.65429049371069,26.22354850965251,27.865548530612248,98.61992723076924],"xaxis":"x","y":["Belice","Aruba","Bolivia","Argentina","Uruguay","Costa Rica","Panam\u00e1","Rep\u00fablica Dominicana","Jamaica","Nicaragua","Paraguay","El Salvador","Honduras","Guatemala","Brasil","Chile","Per\u00fa","Ecuador","Colombia","M\u00e9xico"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77 ...

# %%
#Argentina imports. Anual Mean 2016-2020 

# SLICING & GROUPING
imp_arg = df1[df1['partner_iso'] == 'ARG']
imp_arg = imp_arg.groupby(['reporter']).agg(total =  ('trade_value_usd', sum),
                                                          media_value =('trade_value_usd', 'mean'),
                                                          first = ('trade_value_usd', 'first'),last =('trade_value_usd', 'last'), last_year = ('year','last'))
imp_arg = imp_arg.reset_index()

imp_arg.reporter = imp_arg.reporter.replace('Bolivia (Plurinational State of)', 'Bolivia')

df = imp_arg
sd = df.nlargest(15,'media_value')
fd = sd.sort_values(by='media_value', ascending = True)

fig = px.bar(fd, x="media_value", y="reporter", orientation='h',
             hover_data=['reporter','media_value', 'first', 'last','last_year'],
             height=600,
             title='A qué países le exporta Argentina? Top 15 importadores. Promedio anual 2016-2020',
             labels={'media_value': 'Importaciones (millones USD)', 'reporter':'País'})

#py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b7ca1692-3724-4b77-b1c3-1cf4be03567d" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7ca1692-3724-4b77-b1c3-1cf4be03567d")) {                    Plotly.newPlot(                        "b7ca1692-3724-4b77-b1c3-1cf4be03567d",                        [{"alignmentgroup":"True","customdata":[[319.142302,0.392673,2016.0],[110.383436,97.362392,2016.0],[197.152513,0.835625,2020.0],[143.362942,142.463606,2016.0],[321.947221,2.444981,2016.0],[209.81019,290.989009,2016.0],[582.23152,0.423054,2016.0],[443.832071,366.630823,2016.0],[628.327362,624.851738,2016.0],[408.715126,298.85902,2016.0],[623.062611,515.947316,2016.0],[369.065006,511.934735,2016.0],[1015.927684,0.218721,2016.0],[635.901212,556.168806,2016.0],[1249.773094,9.001771,2017.0]],"hovertemplate":"Importaciones (millones USD)=%{x}<br>Pa\u00eds=%{y}<br>first=%{customdata[0]}<br>last=%{customdata[1]}<br>last_year=%{customdata[2]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[122.7412262,127.6768204,138.53861266666667,150.4215334,166.7633742,185.745542,260.8061725,298.12363885714285,309.41895466666665,340.0716592,385.64588985714283,440.4998705,497.70208030000003,529.1845402,727.8697202999999],"xaxis":"x","y":["Philippines","Greece","Saudi Arabia","Ireland","Australia","Netherlands","Malaysia","United Kingdom","Spain","Turkey","Italy","Algeria","Indonesia","Poland","Viet Nam"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333," ...

# %%
#Loadings matrix to Table
df = loadings_matrix
df[['PC1', 'PC2', 'PC3', 'PC4', 'PC5']] = df[['PC1', 'PC2', 'PC3', 'PC4', 'PC5']].round(3) 

fig = go.Figure(data=[go.Table(
    columnorder = [1,2,3,4,5,6],
    columnwidth = [110, 80, 80, 80, 80, 80],
    header=dict(values=list(df.columns),
                fill_color='rgba(92,140,164)',
                align='center'),
    cells=dict(values=[df.Referencia, df.PC1, df.PC2, df.PC3, df.PC4, df.PC5],
               fill_color='rgba(196,196,196)',
               align='center'))
])
py.iplot(fig)
#fig.show()
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~gabrielfernande.z/33.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
#Variables description to Table
df = variables 
fig = go.Figure(data=[go.Table(
    columnorder = [1,2],
    columnwidth = [80, 200],
    header=dict(values=list(df.columns),
                fill_color='rgba(92,140,164)',
                align='center'),
    cells=dict(values=[df.Referencia, df.Descripción],
               fill_color='rgba(196,196,196)',
               align='center'))
])
py.iplot(fig)
#fig.show()
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~gabrielfernande.z/31.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
df2 = pd.merge(impo_global, cod_paises, on = 'reporter_iso', how = 'inner')
df2.reporter = df2.reporter.replace('Reino Unido de Gran Bretaña e Irlanda del Norte', 'Reino Unido')

# %%
df2 = df2.set_index('index')
df2 = df2[['reporter', 'total', 'media_value', 'ARG_part', 'UE_part','CHN_part', 'Resto_part', 'last_year']]
df2=df2.rename(columns = {'total':'total (Mill.)'})

# %%
#Imports general data

fig = go.Figure(data=[go.Table(
    columnorder = [1,2,3,4,5,6,7,8],
    columnwidth = [110, 80, 80, 80, 80, 80, 80],
    header=dict(values=list(df2.columns),
                fill_color='rgba(92,140,164)',
                align='center'),
    cells=dict(values= [df2.reporter, df2['total (Mill.)'], df2.media_value, df2.ARG_part, df2.UE_part, df2.CHN_part, df2.Resto_part, df2.last_year],
               fill_color='rgba(196,196,196)',
               align='center'))
])
py.iplot(fig)
#fig.show()
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~gabrielfernande.z/39.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# RANKING PC1
df = df_vf
sd = df.nlargest(20,'PC1')
fd = sd.sort_values(by='PC1', ascending = True)

fig = px.bar(fd, x="PC1", y="reporter", orientation='h',
             hover_data=['reporter_iso','media_value', 'ARG_part', 'UE_part','CHN_part'],
             height=600,
             title='Top 20 Ranking de países según PC1',
             labels={'PC1': 'Componente Principal #1', 'reporter':'País'})

#py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e674a676-3abb-4eb7-9a3c-f363e5595420" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e674a676-3abb-4eb7-9a3c-f363e5595420")) {                    Plotly.newPlot(                        "e674a676-3abb-4eb7-9a3c-f363e5595420",                        [{"alignmentgroup":"True","customdata":[["THA",27.86,6.0,1.71,81.14],["UKR",5.48,0.0,5.12,51.99],["POL",33.33,14.0,0.64,61.69],["CAN",25.68,0.0,1.29,52.5],["ARE",4.54,11.0,0.34,71.23],["BGR",3.85,0.0,5.01,51.78],["AUS",19.44,20.0,1.2,60.46],["DEU",46.47,1.0,2.72,60.96],["SVK",3.71,0.0,0.47,59.92],["HUN",9.52,0.0,0.05,54.02],["LTU",4.99,5.0,1.25,51.39],["VNM",59.51,30.0,3.15,60.93],["EST",1.67,0.0,0.35,56.31],["DNK",19.45,9.0,2.46,57.0],["BEL",31.8,2.0,0.54,52.13],["NZL",9.57,14.0,0.66,72.13],["MLT",1.48,0.0,0.15,52.18],["NLD",31.45,3.0,2.77,67.5],["IRL",14.67,12.0,0.62,56.17],["LUX",1.92,0.0,0.47,52.53]],"hovertemplate":"Componente Principal #1=%{x}<br>Pa\u00eds=%{y}<br>reporter_iso=%{customdata[0]}<br>media_value=%{customdata[1]}<br>ARG_part=%{customdata[2]}<br>UE_part=%{customdata[3]}<br>CHN_part=%{customdata[4]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[2.17,2.2,2.22,2.26,2.26,2.36,2.36,2.43,2.46,2.76,2.84,2.9,2.99,2.99,3.02,3.1,3.18,3.25,3.95,5.24],"xaxis":"x","y":["Tailandia","Ucrania","Polonia","Canad\u00e1","Emiratos \u00c1rabes Unidos","Bulgaria","Australia","Alemania","Eslovaquia","Hungr\u00eda","Lituania","Viet Nam","Estonia","Dinamarca","B\u00e9lgica","Nueva Zelandia","Malta","Pa\u00edses Bajos","Irlanda","Luxemburgo"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d ...

# %%
# Cluster #1 imports. Annual Mean 2016-2020
df = df_vf.loc[df_vf['cluster'].isin([0])]
sd = df.nlargest(20,'media_value')
fd = sd.sort_values(by='media_value', ascending = True)


fig = px.bar(fd, x="media_value", y="reporter", orientation='h',
             hover_data=['reporter_iso','media_value', 'ARG_part', 'UE_part','CHN_part'],
             height=600,
             title='Top 20 Importaciones de países Cluster #1. Promedio anual 2016-2020',
             labels={'media_value': 'Importaciones (millones USD)', 'reporter':'País'})

#py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e4ddf22f-9641-4568-9238-97afa87ff2fe" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4ddf22f-9641-4568-9238-97afa87ff2fe")) {                    Plotly.newPlot(                        "e4ddf22f-9641-4568-9238-97afa87ff2fe",                        [{"alignmentgroup":"True","customdata":[["GRD",0.0,0.0,78.03],["CPV",0.0,0.01,51.06],["ATG",0.0,0.04,74.42],["LCA",0.0,0.01,88.42],["BRB",0.0,0.07,69.97],["MNE",0.0,0.07,85.95],["LSO",0.0,0.01,94.76],["MOZ",0.0,0.11,97.16],["BHS",0.0,0.01,50.28],["SUR",0.0,0.02,66.06],["AGO",0.0,0.47,67.33],["BLZ",0.0,0.0,87.56],["FJI",0.0,0.04,99.23],["YEM",39.0,0.15,53.43],["AZE",12.0,0.11,81.04],["AFG",0.0,0.04,99.84],["NAM",0.0,0.06,99.33],["BWA",0.0,0.0,99.98],["ZWE",0.0,0.03,99.88],["NIC",0.0,0.01,75.07]],"hovertemplate":"Importaciones (millones USD)=%{x}<br>Pa\u00eds=%{y}<br>reporter_iso=%{customdata[0]}<br>ARG_part=%{customdata[1]}<br>UE_part=%{customdata[2]}<br>CHN_part=%{customdata[3]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[0.18,0.31,0.41,0.59,0.64,0.7,0.78,1.05,1.07,1.12,1.18,1.37,1.61,1.99,1.99,3.36,3.38,3.71,4.83,5.3],"xaxis":"x","y":["Granada","Cabo Verde","Antigua y Barbuda","Santa Luc\u00eda","Barbados","Montenegro","Lesotho","Mozambique","Bahamas","Suriname","Angola","Belice","Fiji","Yemen","Azerbaiy\u00e1n","Afganist\u00e1n","Namibia","Botswana","Zimbabwe","Nicaragua"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9 ...

# %%
# Cluster #2 imports. Annual Mean 2016-2020
df = df_vf.loc[df_vf['cluster'].isin([1])]
sd = df.nlargest(20,'media_value')
fd = sd.sort_values(by='media_value', ascending = True)


fig = px.bar(fd, x="media_value", y="reporter", orientation='h',
             hover_data=['reporter_iso','media_value', 'ARG_part', 'UE_part','CHN_part'],
             height=600,
             title='Top 20 Importaciones de países Cluster #2. Promedio anual 2016-2020',
             labels={'media_value': 'Importaciones (millones USD)', 'reporter':'País'})

#py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="adb55452-2bcd-4b51-83f4-2fd00b23af7a" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("adb55452-2bcd-4b51-83f4-2fd00b23af7a")) {                    Plotly.newPlot(                        "adb55452-2bcd-4b51-83f4-2fd00b23af7a",                        [{"alignmentgroup":"True","customdata":[["GUY",0.0,0.01,65.11],["UGA",0.0,0.5,70.88],["TJK",8.0,0.14,86.46],["SDN",0.0,2.08,64.72],["MDG",2.0,0.19,69.68],["CMR",29.0,0.14,51.89],["KEN",0.0,0.81,88.73],["SEN",28.0,0.09,54.23],["GHA",20.0,1.08,60.46],["NGA",0.0,4.05,61.04],["CIV",23.0,0.18,54.67],["PAK",18.0,6.2,61.43],["LKA",0.0,1.4,67.02],["MMR",0.0,1.88,77.36],["NPL",0.0,1.4,95.39],["KHM",2.0,1.52,88.32],["GTM",0.0,0.6,60.77],["IND",0.0,6.29,80.18],["EGY",32.0,1.47,54.57],["CHN",0.0,0.04,73.91]],"hovertemplate":"Importaciones (millones USD)=%{x}<br>Pa\u00eds=%{y}<br>reporter_iso=%{customdata[0]}<br>ARG_part=%{customdata[1]}<br>UE_part=%{customdata[2]}<br>CHN_part=%{customdata[3]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[0.86,0.94,1.36,1.63,1.69,1.7,1.75,1.76,1.92,2.02,2.5,3.01,4.26,4.64,4.87,6.75,9.41,9.51,12.68,15.27],"xaxis":"x","y":["Guyana","Uganda","Tayikist\u00e1n","Sud\u00e1n","Madagascar","Camer\u00fan","Kenya","Senegal","Ghana","Nigeria","C\u00f4te d'Ivoire","Pakist\u00e1n","Sri Lanka","Myanmar","Nepal","Camboya","Guatemala","India","Egipto","China"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4 ...

# %%
# Cluster #3 imports. Annual Mean 2016-2020
df = df_vf.loc[df_vf['cluster'].isin([2])]
sd = df.nlargest(20,'media_value')
fd = sd.sort_values(by='media_value', ascending = True)


fig = px.bar(fd, x="media_value", y="reporter", orientation='h',
             hover_data=['reporter_iso','media_value', 'ARG_part', 'UE_part','CHN_part'],
             height=600,
             title='Top 20 Importaciones de países Cluster #3. Promedio anual 2016-2020',
             labels={'media_value': 'Importaciones (millones USD)', 'reporter':'País'})

#py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f555d847-3605-495c-9d8c-7e715754b861" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f555d847-3605-495c-9d8c-7e715754b861")) {                    Plotly.newPlot(                        "f555d847-3605-495c-9d8c-7e715754b861",                        [{"alignmentgroup":"True","customdata":[["SRB",0.0,0.32,57.43],["ARG",0.0,10.73,74.61],["URY",17.0,0.24,78.45],["LVA",2.0,0.18,51.03],["BGR",0.0,5.01,51.78],["LTU",5.0,1.25,51.39],["UKR",0.0,5.12,51.99],["PRY",9.0,0.37,87.56],["FIN",0.0,2.43,56.91],["NZL",14.0,0.66,72.13],["SWE",0.0,1.63,64.71],["BRA",1.0,12.27,56.04],["AUT",0.0,0.28,62.69],["AUS",20.0,1.2,60.46],["DNK",9.0,2.46,57.0],["CAN",0.0,1.29,52.5],["THA",6.0,1.71,81.14],["FRA",1.0,0.5,67.64],["NLD",3.0,2.77,67.5],["DEU",1.0,2.72,60.96]],"hovertemplate":"Importaciones (millones USD)=%{x}<br>Pa\u00eds=%{y}<br>reporter_iso=%{customdata[0]}<br>ARG_part=%{customdata[1]}<br>UE_part=%{customdata[2]}<br>CHN_part=%{customdata[3]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[1.99,2.83,2.94,3.7,3.85,4.99,5.48,5.51,6.25,9.57,10.93,11.26,13.53,19.44,19.45,25.68,27.86,31.31,31.45,46.47],"xaxis":"x","y":["Serbia","Argentina","Uruguay","Letonia","Bulgaria","Lituania","Ucrania","Paraguay","Finlandia","Nueva Zelandia","Suecia","Brasil","Austria","Australia","Dinamarca","Canad\u00e1","Tailandia","Francia","Pa\u00edses Bajos","Alemania"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"# ...

# %%
# Cluster #4 imports. Annual Mean 2016-2020
df = df_vf.loc[df_vf['cluster'].isin([3])]
sd = df.nlargest(20,'media_value')
fd = sd.sort_values(by='media_value', ascending = True)


fig = px.bar(fd, x="media_value", y="reporter", orientation='h',
             hover_data=['reporter_iso','media_value', 'ARG_part', 'UE_part','CHN_part'],
             height=600,
             title='Top 20 Importaciones de países Cluster #4. Promedio anual 2016-2020',
             labels={'media_value': 'Importaciones (millones USD)', 'reporter':'País'})

#py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9c490998-0665-4a0b-85ae-a06b43b3ec3e" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c490998-0665-4a0b-85ae-a06b43b3ec3e")) {                    Plotly.newPlot(                        "9c490998-0665-4a0b-85ae-a06b43b3ec3e",                        [{"alignmentgroup":"True","customdata":[["BLR",14.0,1.02,75.78],["NOR",0.0,1.03,58.05],["MAR",16.0,0.58,50.68],["ROU",3.0,0.12,64.06],["PRT",3.0,0.02,50.7],["SAU",24.0,0.33,61.96],["TUR",29.0,1.14,56.31],["CHL",14.0,1.0,74.53],["MYS",29.0,1.87,63.32],["PER",2.0,0.84,84.44],["ECU",7.0,0.29,76.58],["ESP",17.0,0.74,58.82],["COL",0.0,1.09,62.37],["PHL",9.0,1.12,55.08],["POL",14.0,0.64,61.69],["ITA",15.0,0.56,57.67],["GBR",9.0,2.1,56.26],["JPN",0.0,12.12,69.21],["IDN",22.0,0.97,71.14],["MEX",0.0,0.75,52.51]],"hovertemplate":"Importaciones (millones USD)=%{x}<br>Pa\u00eds=%{y}<br>reporter_iso=%{customdata[0]}<br>ARG_part=%{customdata[1]}<br>UE_part=%{customdata[2]}<br>CHN_part=%{customdata[3]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[8.57,8.67,10.33,11.23,12.92,13.39,13.97,14.44,17.34,20.65,26.22,26.23,27.87,30.23,33.33,36.2,39.29,40.59,55.63,98.62],"xaxis":"x","y":["Belar\u00fas","Noruega","Marruecos","Rumania","Portugal","Arabia Saudita","Turqu\u00eda","Chile","Malasia","Per\u00fa","Ecuador","Espa\u00f1a","Colombia","Filipinas","Polonia","Italia","Reino Unido","Jap\u00f3n","Indonesia","M\u00e9xico"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"] ...

# %%
# Cluster #5 imports. Annual Mean 2016-2020
df = df_vf.loc[df_vf['cluster'].isin([4])]
sd = df.nlargest(20,'media_value')
fd = sd.sort_values(by='media_value', ascending = True)


fig = px.bar(fd, x="media_value", y="reporter", orientation='h',
             hover_data=['reporter_iso','media_value', 'ARG_part', 'UE_part','CHN_part'],
             height=600,
             title='Top 20 Importaciones de países Cluster #5. Promedio anual 2016-2020',
             labels={'media_value': 'Importaciones (millones USD)', 'reporter':'País'})

#py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d08dc9aa-f935-4a2c-b0e8-19c73ed48adc" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d08dc9aa-f935-4a2c-b0e8-19c73ed48adc")) {                    Plotly.newPlot(                        "d08dc9aa-f935-4a2c-b0e8-19c73ed48adc",                        [{"alignmentgroup":"True","customdata":[["MLT",0.0,0.15,52.18],["LUX",0.0,0.47,52.53],["SVK",0.0,0.47,59.92],["CYP",15.0,0.06,51.87],["ARE",11.0,0.34,71.23],["SVN",0.0,0.6,82.27],["HUN",0.0,0.05,54.02],["IRL",12.0,0.62,56.17],["BEL",2.0,0.54,52.13],["VNM",30.0,3.15,60.93]],"hovertemplate":"Importaciones (millones USD)=%{x}<br>Pa\u00eds=%{y}<br>reporter_iso=%{customdata[0]}<br>ARG_part=%{customdata[1]}<br>UE_part=%{customdata[2]}<br>CHN_part=%{customdata[3]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[1.48,1.92,3.71,3.79,4.54,5.64,9.52,14.67,31.8,59.51],"xaxis":"x","y":["Malta","Luxemburgo","Eslovaquia","Chipre","Emiratos \u00c1rabes Unidos","Eslovenia","Hungr\u00eda","Irlanda","B\u00e9lgica","Viet Nam"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333, ...

# %%
df_world = df1.loc[df1['partner_iso'].isin(['WLD'])]
df_world = df_world.sort_values(by=['reporter'], ascending = [True]).groupby(['reporter','reporter_iso', 'year']).agg(total =  ('trade_value_usd', sum))
df_world['%-Change']=df_world.groupby(['reporter', 'reporter_iso'])['total'].apply(lambda x: x/x.shift(1)-1).fillna(0)*100
df_mean_var = df_world.sort_values(by=['reporter'], ascending = [True]).groupby(['reporter','reporter_iso']).agg(mean_var =  ('%-Change', 'mean'))
df_mean_var['mean_var'] = df_mean_var['mean_var'].round(2)

# %%
#Merge de bases de variables + importaciones
df_pc_var = pd.merge(df_vf, df_mean_var, on = 'reporter_iso', how = 'inner')
df_pc_var.shape
# Out:
# (132, 26)

# %%
# value column equals to 0.0
indexNames = df_pc_var[(df_pc_var['reporter'] == 'Níger')].index
# Delete these row indexes from dataFrame
df_pc_var.drop(indexNames , inplace=True)

# %%
# value column equals to 0.0
indexNames = df_pc_var[(df_pc_var['reporter'] == 'Panamá')].index
# Delete these row indexes from dataFrame
df_pc_var.drop(indexNames , inplace=True)

# %%
# PCA and Clusters Scatter Plot

fig = px.scatter(df_pc_var, x=df_pc_var['PC1'], y=df_pc_var['mean_var'], color=df_pc_var['cluster'],hover_data = ['reporter_iso', 'reporter'], color_discrete_sequence=px.colors.qualitative.Antique,
                 labels={'PC1': 'Componente Principal #1', 'mean_var':'Variación % - Promedio anual'})

#py.iplot(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ff0c0e15-a1bc-4a09-8e17-0c5a0f6731a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff0c0e15-a1bc-4a09-8e17-0c5a0f6731a4")) {                    Plotly.newPlot(                        "ff0c0e15-a1bc-4a09-8e17-0c5a0f6731a4",                        [{"customdata":[["AFG","Afganist\u00e1n"],["AGO","Angola"],["ALB","Albania"],["ARE","Emiratos \u00c1rabes Unidos"],["ARG","Argentina"],["ARM","Armenia"],["ATG","Antigua y Barbuda"],["AUS","Australia"],["AUT","Austria"],["AZE","Azerbaiy\u00e1n"],["BEL","B\u00e9lgica"],["BEN","Benin"],["BFA","Burkina Faso"],["BGR","Bulgaria"],["BHS","Bahamas"],["BIH","Bosnia y Herzegovina"],["BLR","Belar\u00fas"],["BLZ","Belice"],["BRA","Brasil"],["BRB","Barbados"],["BWA","Botswana"],["CAN","Canad\u00e1"],["CHE","Suiza"],["CHL","Chile"],["CHN","China"],["CIV","C\u00f4te d'Ivoire"],["CMR","Camer\u00fan"],["COG","Congo"],["COL","Colombia"],["CPV","Cabo Verde"],["CRI","Costa Rica"],["CYP","Chipre"],["DEU","Alemania"],["DNK","Dinamarca"],["DOM","Rep\u00fablica Dominicana"],["ECU","Ecuador"],["EGY","Egipto"],["ESP","Espa\u00f1a"],["EST","Estonia"],["ETH","Etiop\u00eda"],["FIN","Finlandia"],["FJI","Fiji"],["FRA","Francia"],["GBR","Reino Unido"],["GEO","Georgia"],["GHA","Ghana"],["GIN","Guinea"],["GMB","Gambia"],["GRC","Grecia"],["GRD","Granada"],["GRL","Dinamarca"],["GTM","Guatemala"],["GUY","Guyana"],["HND","Honduras"],["HRV","Croacia"],["HUN","Hungr\u00eda"],["IDN","Indonesia"],["IND","India"],["IRL","Irlanda"],["ISL","Islandia"],["ISR","Israel"],["ITA","Italia"],["JAM","Jamaica"],["JOR","Jordania"],["JPN","Jap\u00f3n"],["KAZ","Kazajst\u00e1n"],["KEN","Kenya"],["KGZ","Kirguist\u00e1n"],["KHM","Camboya"],["KWT","Kuwait"],["LBN","L\u00edbano"],["LCA","Santa Luc\u00eda"],["LKA","Sri Lanka"],["LSO","Lesotho"],["LTU","Lituania"],["LUX","Luxemburgo"],["LVA","Letonia"],["MAR","Marruecos"],["MDG","Madagascar"],["MEX","M\u00e9xico"],["MLI","Mal\u00ed"],["MLT","Malta"],["MMR","Myanmar"],["MNE","Montenegro"],["MNG","Mongolia"],["MOZ","Mozambique"],["MUS","Mauricio"],["MWI","Malawi"],["MYS","Malasia"],["NAM","Namibia"],["NGA","Nigeria"],["NIC","Nicaragua"],["NLD","Pa\u00edses Bajos"],["NOR","Noruega"],["NPL","Nepal"],["NZL","Nueva Zelandia"],["OMN","Om\u00e1n"],["PAK","Pakist\u00e1n"],["PER","Per\u00fa"],["PHL","Filipinas"],["POL","Polonia"],["PRT","Portugal"],["PRY","Paraguay"],["PYF","Francia"],["ROU","Rumania"],["RWA","Rwanda"],["SAU","Arabia Saudita"],["SDN","Sud\u00e1n"],["SEN","Senegal"],["SLE","Sierra Leona"],["SLV","El Salvador"],["SRB","Serbia"],["SUR","Suriname"],["SVK","Eslovaquia"],["SVN","Eslovenia"],["SWE","Suecia"],["TGO","Togo"],["THA","Tailandia"],["TJK","Tayikist\u00e1n"],["TUN","T\u00fanez"],["TUR","Turqu\u00eda"],["UGA","Uganda"],["UKR","Ucrania"],["URY","Uruguay"],["UZB","Uzbekist\u00e1n"],["VNM","Viet Nam"],["YEM","Yemen"],["ZAF","Sud\u00e1frica"],["ZMB","Zambia"],["ZWE","Zimbabwe"]],"hovertemplate":"Componente Principal #1=%{x}<br>Variaci\u00f3n % - Promedio anual=%{y}<br>reporter_iso=%{customdata[0]}<br>reporter=%{customdata[1]}<br>cluster=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0,0,3,4,2,3,0,2,2,0,4,1,1,2,0,3,3,0,2,0,0,2,3,3,1,1,1,3,3,0,3,4,2,2,3,3,1,3,2,1,2,0,2,3,3,1,1,0,3,0,2,1,1,3,3,4,3,1,4,3,3,3,3,3,3,3,1,3,1,3,3,0,1,0,2,4,2,3,1,3,1,4,1,0,3,0,3,1,3,0,1,0,2,3,1,2,3,1,3,3,3,3,2,2,3,1,3,1,1,1,3,2,0,4,4,2,1,2,1,3,3,1,2,2,3,4,0,3,1,0],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-4.75,-1.83,0.56,2.26,0.54,0.07,-1.39,2.36,1.91,-1.24,3.02,-1.33,-1.69,2.36,-2.33,0.21,1.12,-1.43,0.42,-1.56,-1.96,2.26,1.46,0.56,0.09,-1.0,-1.51,0.32,-0.17,-2.73,0.23,1.44,2.43,2.99,-0.28,-0.97,-1.29,1.8,2.99,-3.29,1.56,-1.67,1.76,1. ...
